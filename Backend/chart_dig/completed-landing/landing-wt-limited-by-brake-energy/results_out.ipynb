# %%
import os
os.chdir("../..")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\mcdel\digitized-charts

# %%
TOP_FOLDER = "completed-landing/landing-wt-limited-by-brake-energy"

# %%
DIG_FILE_NAME = "brake energy temp dev.dig"
INPUT = "oat"
OUTPUT = "uncor_1"
INTERP_VAL = "t_dev"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_1, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_1 = linear_interpolate( scale_vals_1, {
# 	lin(std::vector<double>{28.363, 32.066, 36.415, 40.355, 44.440, 48.438, 52.466, 56.289, 59.767}, // tempdev+45
# 	std::vector<double>{128.869, 134.040, 139.987, 146.044, 152.001, 157.468, 164.011, 169.709, 175.087}, oat),
# 	lin(std::vector<double>{23.314, 27.373, 31.340, 35.353, 39.403, 43.379, 47.291, 51.323, 53.796}, // tempdev+40
# 	std::vector<double>{130.228, 135.739, 141.177, 147.569, 153.499, 158.990, 165.286, 171.249, 175.108}, oat),
# 	lin(std::vector<double>{13.253, 17.396, 21.279, 25.320, 29.287, 33.337, 37.240, 39.179, 41.806}, // tempdev+30
# 	std::vector<double>{132.924, 138.760, 144.133, 150.120, 156.189, 162.020, 168.468, 171.116, 175.061}, oat),
# 	lin(std::vector<double>{3.182, 7.297, 11.307, 15.247, 19.339, 23.361, 27.290, 30.010}, // tempdev+20
# 	std::vector<double>{135.700, 141.664, 147.184, 153.106, 158.856, 165.058, 171.089, 175.072}, oat),
# 	lin(std::vector<double>{-6.789, -2.732, 1.258, 5.244, 9.202, 13.224, 17.856}, // tempdev+10
# 	std::vector<double>{138.655, 144.610, 150.115, 156.377, 162.065, 167.945, 175.068}, oat),
# 	lin(std::vector<double>{-16.832, -12.808, -8.865, -4.823, -1.059, 3.115, 6.102}, // tempdev0
# 	std::vector<double>{141.670, 147.732, 153.426, 159.668, 165.119, 171.013, 175.044}, oat),
# 	lin(std::vector<double>{-26.966, -22.837, -18.780, -14.840, -10.945, -6.215}, // tempdev_10
# 	std::vector<double>{145.145, 150.971, 157.012, 163.006, 168.388, 175.047}, oat),
# 	lin(std::vector<double>{-37.014, -32.889, -28.844, -24.892, -20.981, -18.471}, // tempdev_20
# 	std::vector<double>{148.718, 154.721, 160.798, 166.518, 171.485, 175.021}, oat),
# 	lin(std::vector<double>{-47.119, -42.930, -38.962, -34.964, -31.332}, // tempdev_30
# 	std::vector<double>{152.675, 158.859, 164.473, 170.341, 175.047}, oat),
# 	lin(std::vector<double>{-57.098, -52.707, -48.943, -44.551}, // tempdev_40
# 	std::vector<double>{156.661, 162.877, 168.255, 175.076}, oat),
# 	lin(std::vector<double>{-61.816, -60.175, -58.037, -54.010, -50.686}, // tempdev_45
# 	std::vector<double>{158.459, 161.530, 165.050, 170.010, 175.080}, oat),
# }, t_dev);

# %%
DIG_FILE_NAME = "brake energy press alt.dig"
INPUT = "uncor_1"
OUTPUT = "uncor_2"
INTERP_VAL = "press_alt_1000s"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_2, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_2 = linear_interpolate( scale_vals_2, {
# 	lin(std::vector<double>{56.362, 41.268, 37.100}, // pressalt2
# 	std::vector<double>{169.788, 174.149, 175.034}, uncor_1),
# 	lin(std::vector<double>{52.340, 47.384, 37.366, 27.185, 17.249, 13.267}, // pressalt4
# 	std::vector<double>{163.950, 165.306, 168.444, 171.110, 174.085, 175.047}, uncor_1),
# 	lin(std::vector<double>{48.353, 43.385, 33.367, 23.094, 3.024, -9.884}, // pressalt6
# 	std::vector<double>{157.471, 158.999, 162.008, 164.970, 170.992, 175.026}, uncor_1),
# 	lin(std::vector<double>{44.498, 39.523, 19.327, 9.089, -0.987, -11.004, -20.890, -29.723}, // pressalt8
# 	std::vector<double>{152.034, 153.506, 158.916, 162.108, 165.146, 168.473, 171.515, 175.042}, uncor_1),
# 	lin(std::vector<double>{40.296, 35.382, 25.320, 15.272, 5.364, -5.010, -14.721, -24.763, -29.940, -40.332, -44.938, -47.168}, // pressalt10
# 	std::vector<double>{146.060, 147.547, 150.141, 153.088, 156.354, 159.736, 163.004, 166.538, 168.452, 172.465, 174.318, 175.029}, uncor_1),
# 	lin(std::vector<double>{36.333, 31.386, 21.316, 1.312, -8.786, -18.838, -28.960, -39.058, -49.064, -54.065}, // pressalt12
# 	std::vector<double>{140.005, 141.194, 144.156, 150.189, 153.436, 156.993, 160.861, 164.569, 168.269, 170.022}, uncor_1),
# 	lin(std::vector<double>{32.173, 27.327, 17.386, 7.325, -2.767, -12.785, -22.803, -32.992, -52.633, -57.976}, // pressalt14
# 	std::vector<double>{134.045, 135.762, 138.778, 141.691, 144.610, 147.740, 151.011, 154.851, 162.910, 164.990}, uncor_1),
# 	lin(std::vector<double>{28.252, 13.382, -6.962, -16.978, -26.981, -36.999, -46.958, -57.092, -61.992}, // pressalt16
# 	std::vector<double>{128.926, 132.865, 138.604, 141.675, 145.134, 148.699, 152.664, 156.651, 158.496}, uncor_1),
# }, press_alt_1000s);

# %%
DIG_FILE_NAME = "brake-energy-runway-slope.dig"
INPUT = "slope"
OUTPUT = "uncor_3"
INTERP_VAL = "uncor_2"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_3, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_3 = linear_interpolate( scale_vals_3, {
# 	lin(std::vector<double>{-0.133, 0.901, 3.074, 4.021, 4.984}, // uncorr80
# 	std::vector<double>{80.000, 80.813, 84.470, 87.223, 89.801}, slope),
# 	lin(std::vector<double>{-4.978, -0.886, 1.083, 3.108, 5.033}, // uncorr85
# 	std::vector<double>{80.724, 84.351, 86.132, 89.774, 94.833}, slope),
# 	lin(std::vector<double>{-4.997, -1.038, 0.953, 3.156, 4.964}, // uncorr90
# 	std::vector<double>{84.990, 89.010, 91.085, 95.037, 99.705}, slope),
# 	lin(std::vector<double>{-4.994, 0.990, 3.033, 5.008}, // uncorr95
# 	std::vector<double>{89.229, 96.310, 99.900, 104.544}, slope),
# 	lin(std::vector<double>{-5.008, -3.982, -0.058, 1.342, 2.973, 5.041}, // uncorr100
# 	std::vector<double>{93.392, 94.891, 100.101, 101.996, 104.954, 109.592}, slope),
# 	lin(std::vector<double>{-5.004, -0.039, 1.260, 2.910, 5.039}, // uncorr105
# 	std::vector<double>{97.691, 105.106, 106.995, 109.953, 114.536}, slope),
# 	lin(std::vector<double>{-5.024, -3.272, -0.078, 2.890, 5.051}, // uncorr110
# 	std::vector<double>{101.883, 104.901, 109.960, 114.965, 119.468}, slope),
# 	lin(std::vector<double>{-5.017, -2.969, -0.055, 2.745, 5.043}, // uncorr115
# 	std::vector<double>{106.163, 109.946, 114.991, 119.970, 124.322}, slope),
# 	lin(std::vector<double>{-5.016, -2.770, -0.087, 2.710, 5.027}, // uncorr120
# 	std::vector<double>{110.408, 114.958, 119.950, 125.028, 129.248}, slope),
# 	lin(std::vector<double>{-5.005, -2.520, -0.059, 5.018}, // uncorr125
# 	std::vector<double>{114.859, 120.021, 125.042, 134.431}, slope),
# 	lin(std::vector<double>{-4.993, -2.357, -1.035, -0.052, 2.584, 5.053}, // uncorr130
# 	std::vector<double>{119.235, 125.008, 127.993, 129.981, 135.125, 139.529}, slope),
# 	lin(std::vector<double>{-5.012, -1.019, -0.028, 2.522, 5.042}, // uncorr135
# 	std::vector<double>{123.936, 133.014, 134.995, 140.131, 144.659}, slope),
# 	lin(std::vector<double>{-5.003, -1.071, 2.484, 5.024}, // uncorr140
# 	std::vector<double>{128.522, 137.773, 145.080, 149.839}, slope),
# 	lin(std::vector<double>{-5.013, -4.242, -2.886, -2.078, -0.914, 2.516, 5.004}, // uncorr145
# 	std::vector<double>{133.564, 135.147, 138.050, 140.142, 143.061, 150.110, 154.964}, slope),
# 	lin(std::vector<double>{-5.001, -4.199, -3.162, -2.035, -1.175, 1.001, 2.543, 5.035}, // uncorr150
# 	std::vector<double>{138.543, 140.110, 142.165, 145.068, 147.296, 152.081, 155.189, 160.115}, slope),
# 	lin(std::vector<double>{-5.001, -3.305, -2.063, -1.042, -0.058, 2.537, 5.048}, // uncorr155
# 	std::vector<double>{143.616, 147.107, 150.115, 152.778, 154.817, 160.089, 165.688}, slope),
# 	lin(std::vector<double>{-4.976, -2.928, -2.109, -1.053, -0.050, 2.590, 5.008}, // uncorr160
# 	std::vector<double>{148.800, 153.132, 155.146, 157.807, 159.709, 165.229, 171.229}, slope),
# 	lin(std::vector<double>{-5.004, -3.061, -2.172, -1.053, -0.062, 2.633, 4.903}, // uncorr165
# 	std::vector<double>{153.997, 158.038, 160.171, 162.813, 164.701, 170.202, 174.963}, slope),
# 	lin(std::vector<double>{-4.984, -2.201, -0.059, 2.099}, // uncorr170
# 	std::vector<double>{159.151, 165.189, 170.126, 175.026}, slope),
# 	lin(std::vector<double>{-4.948, -2.339, -1.051, -0.196}, // uncorr175
# 	std::vector<double>{164.216, 170.114, 173.201, 174.882}, slope),
# 	lin(std::vector<double>{-4.973, -2.467}, // uncorr180
# 	std::vector<double>{169.307, 174.973}, slope),
# }, uncor_2);

# %%
DIG_FILE_NAME = "brake-energy-wind-corr.dig"
INPUT = "h_t_comp"
OUTPUT = "uncor_4"
INTERP_VAL = "uncor_3"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_3, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_4 = linear_interpolate( scale_vals_3, {
# 	lin(std::vector<double>{0.561, 10.164, 20.155, 30.204, 39.982}, // uncorr80
# 	std::vector<double>{79.987, 83.668, 88.963, 95.007, 99.254}, h_t_comp),
# 	lin(std::vector<double>{-18.934, 0.118, 10.100, 20.190, 30.188, 40.062}, // uncorr85
# 	std::vector<double>{79.908, 84.906, 89.004, 94.409, 100.648, 105.564}, h_t_comp),
# 	lin(std::vector<double>{-20.024, 0.036, 10.125, 20.174, 30.224, 39.943}, // uncorr90
# 	std::vector<double>{83.578, 89.808, 94.387, 99.949, 106.276, 111.721}, h_t_comp),
# 	lin(std::vector<double>{-20.043, -9.955, -0.022, 10.202, 20.019, 30.224, 39.963}, // uncorr95
# 	std::vector<double>{87.505, 91.037, 94.884, 99.747, 105.442, 111.836, 118.014}, h_t_comp),
# 	lin(std::vector<double>{-19.987, -10.008, 0.058, 10.255, 20.159, 30.265, 39.991}, // uncorr100
# 	std::vector<double>{91.421, 95.492, 99.919, 105.134, 110.964, 117.466, 124.297}, h_t_comp),
# 	lin(std::vector<double>{-19.985, -9.972, 0.041, 10.131, 20.221, 30.342, 40.062}, // uncorr105
# 	std::vector<double>{95.351, 100.030, 104.934, 110.498, 116.605, 123.265, 130.574}, h_t_comp),
# 	lin(std::vector<double>{-19.992, -10.003, -0.005, 10.147, 20.190, 30.188, 39.984}, // uncorr110
# 	std::vector<double>{99.341, 104.483, 109.968, 116.008, 122.180, 128.907, 136.796}, h_t_comp),
# 	lin(std::vector<double>{-19.985, -10.013, 0.007, 10.222, 20.106, 30.321, 39.991}, // uncorr115
# 	std::vector<double>{103.211, 108.989, 114.883, 121.477, 127.938, 134.740, 143.023}, h_t_comp),
# 	lin(std::vector<double>{-19.994, -10.081, -0.040, 10.173, 20.171, 30.255, 35.288, 40.052}, // uncorr120
# 	std::vector<double>{107.040, 113.381, 119.917, 126.923, 133.579, 140.649, 145.133, 149.360}, h_t_comp),
# 	lin(std::vector<double>{-20.006, -9.984, 0.007, 10.154, 20.184, 30.195, 34.092, 40.050}, // uncorr125
# 	std::vector<double>{110.983, 117.794, 125.046, 132.339, 139.274, 146.617, 150.146, 155.607}, h_t_comp),
# 	lin(std::vector<double>{-19.962, -9.983, -0.052, 10.212, 30.218, 40.000}, // uncorr130
# 	std::vector<double>{115.004, 122.169, 129.931, 137.823, 152.648, 161.687}, h_t_comp),
# 	lin(std::vector<double>{-20.000, -9.987, -0.061, 10.154, 20.145, 30.211, 40.046}, // uncorr135
# 	std::vector<double>{118.604, 126.639, 135.016, 143.150, 150.726, 158.804, 167.764}, h_t_comp),
# 	lin(std::vector<double>{-20.005, -10.052, 0.075, 10.173, 20.174, 30.282, 39.991}, // uncorr140
# 	std::vector<double>{122.403, 131.027, 140.076, 148.468, 156.377, 164.993, 173.751}, h_t_comp),
# 	lin(std::vector<double>{-20.024, -10.004, -0.021, 10.185, 20.055, 30.279, 34.884}, // uncorr145
# 	std::vector<double>{126.290, 135.513, 145.005, 154.040, 162.200, 171.168, 174.997}, h_t_comp),
# 	lin(std::vector<double>{-19.966, -10.018, -0.052, 10.177, 20.205, 27.488}, // uncorr150
# 	std::vector<double>{130.110, 140.022, 150.038, 159.513, 168.354, 174.988}, h_t_comp),
# 	lin(std::vector<double>{-20.000, -10.004, -4.649, -0.071, 4.723, 9.266, 18.965}, // uncorr155
# 	std::vector<double>{133.921, 144.385, 150.121, 154.949, 160.205, 165.218, 175.014}, h_t_comp),
# 	lin(std::vector<double>{-20.046, -10.003, -0.005, 8.943, 13.247}, // uncorr160
# 	std::vector<double>{137.774, 148.834, 160.092, 170.188, 174.998}, h_t_comp),
# 	lin(std::vector<double>{-20.000, -9.995, 0.021, 8.801}, // uncorr165
# 	std::vector<double>{141.618, 153.260, 165.090, 174.980}, h_t_comp),
# 	lin(std::vector<double>{-20.037, -10.044, 0.075, 4.487}, // uncorr170
# 	std::vector<double>{145.445, 157.695, 170.155, 175.016}, h_t_comp),
# 	lin(std::vector<double>{-20.016, -10.045, -0.261}, // uncorr175
# 	std::vector<double>{149.235, 162.047, 174.894}, h_t_comp),
# 	lin(std::vector<double>{-20.016, -11.036, -3.873}, // uncorr180
# 	std::vector<double>{153.053, 165.203, 174.988}, h_t_comp),
# }, uncor_3);

# %%
DIG_FILE_NAME = "brake-energy-partial-flaps.dig"
INPUT = "flaps"
OUTPUT = "uncor_5"
INTERP_VAL = "uncor_4"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_3, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(asc_vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tasc_vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_5 = linear_interpolate( scale_vals_3, {
# 	lin(asc_vector<double>{100.277, 77.110}, // partial85
# 	asc_vector<double>{84.718, 80.005}, flaps),
# 	lin(asc_vector<double>{100.178, 54.023}, // partial90
# 	asc_vector<double>{89.649, 79.994}, flaps),
# 	lin(asc_vector<double>{34.414, 50.615, 100.124}, // partial95
# 	asc_vector<double>{79.995, 83.956, 94.765}, flaps),
# 	lin(asc_vector<double>{17.017, 50.892, 100.210}, // partial100
# 	asc_vector<double>{80.020, 88.609, 99.735}, flaps),
# 	lin(asc_vector<double>{1.283, 20.145, 50.598, 100.058}, // partial105
# 	asc_vector<double>{80.022, 84.979, 93.064, 104.705}, flaps),
# 	lin(asc_vector<double>{0.991, 50.613, 100.111}, // partial110
# 	asc_vector<double>{84.040, 97.678, 109.731}, flaps),
# 	lin(asc_vector<double>{1.038, 50.419, 100.312}, // partial115
# 	asc_vector<double>{88.056, 102.228, 114.744}, flaps),
# 	lin(asc_vector<double>{0.928, 50.668, 100.268}, // partial120
# 	asc_vector<double>{92.053, 106.813, 119.790}, flaps),
# 	lin(asc_vector<double>{1.083, 50.707, 100.116}, // partial125
# 	asc_vector<double>{96.117, 111.356, 124.771}, flaps),
# 	lin(asc_vector<double>{1.135, 50.932, 100.135}, // partial130
# 	asc_vector<double>{100.165, 116.047, 129.741}, flaps),
# 	lin(asc_vector<double>{1.144, 50.643, 100.201}, // partial135
# 	asc_vector<double>{104.236, 120.541, 134.824}, flaps),
# 	lin(asc_vector<double>{1.061, 51.095, 100.236}, // partial140
# 	asc_vector<double>{108.178, 125.232, 139.880}, flaps),
# 	lin(asc_vector<double>{0.844, 50.673, 100.107}, // partial145
# 	asc_vector<double>{112.183, 129.703, 144.804}, flaps),
# 	lin(asc_vector<double>{1.016, 50.522, 100.118}, // partial150
# 	asc_vector<double>{116.198, 134.202, 149.861}, flaps),
# 	lin(asc_vector<double>{1.114, 50.740, 99.900}, // partial155
# 	asc_vector<double>{120.202, 138.894, 154.790}, flaps),
# 	lin(asc_vector<double>{0.869, 50.529, 100.099}, // partial160
# 	asc_vector<double>{124.121, 143.420, 159.888}, flaps),
# 	lin(asc_vector<double>{1.105, 50.415, 99.805}, // partial165
# 	asc_vector<double>{128.147, 147.950, 164.891}, flaps),
# 	lin(asc_vector<double>{0.760, 50.566, 100.212}, // partial170
# 	asc_vector<double>{132.080, 152.596, 169.899}, flaps),
# 	lin(asc_vector<double>{1.013, 50.504, 100.309}, // partial175
# 	asc_vector<double>{136.185, 157.180, 174.956}, flaps),
# 	lin(asc_vector<double>{0.792, 50.495, 86.697}, // partial180
# 	asc_vector<double>{140.087, 161.712, 174.976}, flaps),
# }, uncor_4);

# %%
DIG_FILE_NAME = "brake-energy-engine-corrected.dig"
INPUT = "engine_sel"
OUTPUT = "corrected"
INTERP_VAL = "uncor_5"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_3, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto corrected = linear_interpolate( scale_vals_3, {
# 	lin(std::vector<double>{3.009, 2.001, 0.992, 0.007}, // corr85
# 	std::vector<double>{84.861, 84.025, 82.916, 83.569}, engine_sel),
# 	lin(std::vector<double>{0.013, 1.001, 2.004, 3.021}, // corr90
# 	std::vector<double>{88.015, 87.635, 88.776, 89.782}, engine_sel),
# 	lin(std::vector<double>{0.005, 0.991, 2.001, 3.011}, // corr95
# 	std::vector<double>{92.394, 92.371, 93.650, 94.891}, engine_sel),
# 	lin(std::vector<double>{0.003, 0.989, 2.005, 3.007}, // corr100
# 	std::vector<double>{96.778, 97.067, 98.439, 99.894}, engine_sel),
# 	lin(std::vector<double>{-0.001, 0.988, 2.002, 3.004}, // corr105
# 	std::vector<double>{101.142, 101.858, 103.219, 104.931}, engine_sel),
# 	lin(std::vector<double>{-0.003, 0.991, 2.001, 3.014}, // corr110
# 	std::vector<double>{105.518, 106.538, 107.951, 109.916}, engine_sel),
# 	lin(std::vector<double>{0.001, 0.988, 1.994, 3.010}, // corr115
# 	std::vector<double>{109.849, 111.351, 112.734, 114.939}, engine_sel),
# 	lin(std::vector<double>{0.001, 0.990, 1.998, 3.010}, // corr120
# 	std::vector<double>{114.205, 116.026, 117.530, 119.964}, engine_sel),
# 	lin(std::vector<double>{0.005, 0.993, 1.998, 3.008}, // corr125
# 	std::vector<double>{118.609, 120.802, 122.369, 124.979}, engine_sel),
# 	lin(std::vector<double>{0.001, 0.988, 2.001, 3.006}, // corr130
# 	std::vector<double>{122.984, 125.514, 127.141, 129.966}, engine_sel),
# 	lin(std::vector<double>{0.001, 0.986, 1.997, 3.012}, // corr135
# 	std::vector<double>{127.396, 130.272, 131.886, 135.010}, engine_sel),
# 	lin(std::vector<double>{0.000, 0.987, 1.999, 3.005}, // corr140
# 	std::vector<double>{131.735, 135.001, 136.702, 140.078}, engine_sel),
# 	lin(std::vector<double>{-0.000, 0.990, 1.999, 3.009}, // corr145
# 	std::vector<double>{136.094, 139.770, 141.480, 145.060}, engine_sel),
# 	lin(std::vector<double>{-0.001, 0.993, 1.997, 3.011}, // corr150
# 	std::vector<double>{140.481, 144.481, 146.233, 150.095}, engine_sel),
# 	lin(std::vector<double>{3.010, 2.000, 0.992, -0.004}, // corr155
# 	std::vector<double>{155.075, 151.102, 149.254, 144.826}, engine_sel),
# 	lin(std::vector<double>{-0.003, 0.991, 1.998, 3.004}, // corr160
# 	std::vector<double>{149.165, 153.965, 155.855, 160.089}, engine_sel),
# 	lin(std::vector<double>{-0.003, 0.993, 2.002, 3.001}, // corr165
# 	std::vector<double>{153.545, 158.733, 160.653, 165.131}, engine_sel),
# 	lin(std::vector<double>{-0.001, 0.992, 1.995, 2.998}, // corr170
# 	std::vector<double>{157.938, 163.463, 165.422, 170.056}, engine_sel),
# 	lin(std::vector<double>{-0.003, 0.990, 1.998, 2.980}, // corr175
# 	std::vector<double>{162.261, 168.215, 170.190, 175.034}, engine_sel),
# 	lin(std::vector<double>{0.001, 0.986, 1.996}, // corr180
# 	std::vector<double>{166.684, 172.907, 175.035}, engine_sel),
# }, uncor_5);
