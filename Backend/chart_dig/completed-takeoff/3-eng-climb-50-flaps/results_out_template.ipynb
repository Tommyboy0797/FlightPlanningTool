# %%
import os
os.chdir("../..")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\mcdel\digitized-charts

# %%
TOP_FOLDER = "completed-takeoff/3-eng-climb-50-flaps"

# %%
DIG_FILE_NAME = "3-eng-50-flaps-climb-factor-temp-dev.dig"
INPUT = "t_dev"
OUTPUT = "uncor_1"
INTERP_VAL = "tof"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_1, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_1 = linear_interpolate( scale_vals_1, {
# 	lin(std::vector<double>{-46.207, 2.079, 19.247, 31.587, 37.489, 46.610}, // takeofffactor_neg1
# 	std::vector<double>{-1.010, -1.009, -0.839, -0.597, -0.427, -0.193}, t_dev),
# 	lin(std::vector<double>{-45.134, -0.067, 15.492, 28.368, 35.343, 45.537}, // takeofffactor_0
# 	std::vector<double>{-0.001, -0.016, 0.114, 0.324, 0.493, 0.784}, t_dev),
# 	lin(std::vector<double>{-45.671, -0.067, 16.028, 27.832, 35.879, 46.610}, // takeofffactor_1
# 	std::vector<double>{0.992, 1.001, 1.107, 1.325, 1.535, 1.777}, t_dev),
# 	lin(std::vector<double>{-46.207, 0.469, 17.101, 31.051, 39.098, 47.683}, // takeofffactor_2
# 	std::vector<double>{1.985, 1.994, 2.172, 2.415, 2.633, 2.819}, t_dev),
# 	lin(std::vector<double>{-45.671, -1.677, 13.346, 20.320, 32.660, 40.171, 48.756}, // takeofffactor_3
# 	std::vector<double>{3.003, 3.004, 3.069, 3.222, 3.465, 3.699, 3.844}, t_dev),
# 	lin(std::vector<double>{-45.671, 0.469, 11.736, 24.076, 35.343, 41.781, 47.146}, // takeofffactor_4
# 	std::vector<double>{4.004, 4.005, 4.086, 4.240, 4.530, 4.692, 4.789}, t_dev),
# 	lin(std::vector<double>{-46.207, 0.469, 12.273, 24.076, 35.343, 41.781, 46.073}, // takeofffactor_5
# 	std::vector<double>{5.005, 5.006, 5.079, 5.273, 5.516, 5.693, 5.806}, t_dev),
# 	lin(std::vector<double>{-45.671, 1.006, 23.003, 35.879, 41.244, 47.683}, // takeofffactor_6
# 	std::vector<double>{6.014, 6.015, 6.250, 6.517, 6.735, 6.856}, t_dev),
# 	lin(std::vector<double>{-45.671, -2.213, 11.736, 24.613, 35.879, 46.610}, // takeofffactor_7
# 	std::vector<double>{7.024, 7.025, 7.114, 7.275, 7.534, 7.833}, t_dev),
# }, tof);

# %%
DIG_FILE_NAME = "3-eng-50-flaps-climb-factor-gwt.dig"
INPUT = "uncor_1"
OUTPUT = "climb_factor"
INTERP_VAL = "gwt"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_2, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto climb_factor = linear_interpolate( scale_vals_2, {
# 	lin(std::vector<double>{-1.004, -0.511, 0.001, 0.496, 0.998, 1.499, 2.002, 2.500, 2.797, 3.006, 3.503, 4.003, 4.514, 5.001, 5.617, 5.713, 6.010, 6.229, 6.683, 7.161, 7.321, 7.563, 8.004}, // gwt_80
# 	std::vector<double>{75.740, 76.386, 77.135, 78.431, 79.830, 81.709, 83.836, 86.559, 88.284, 89.477, 94.006, 98.548, 103.946, 110.319, 119.509, 120.898, 125.908, 129.985, 139.851, 150.119, 153.417, 160.090, 171.995}, uncor_1),
# 	lin(std::vector<double>{-1.007, -0.506, -0.003, 0.488, 0.993, 1.501, 1.993, 2.497, 3.005, 3.502, 3.728, 4.000, 4.319, 4.645, 5.016, 5.375, 5.512, 5.638, 5.940, 6.168, 6.412, 6.795, 7.171, 7.518, 7.823, 8.007}, // gwt_90
# 	std::vector<double>{83.789, 85.258, 86.629, 88.170, 89.738, 92.799, 95.757, 99.298, 102.775, 107.538, 109.756, 112.352, 115.622, 119.412, 124.669, 129.795, 132.080, 133.832, 139.882, 144.192, 150.137, 160.069, 170.273, 180.010, 190.215, 195.850}, uncor_1),
# 	lin(std::vector<double>{-1.002, -0.510, -0.006, 0.496, 0.997, 1.501, 2.003, 2.499, 3.004, 3.493, 3.971, 4.374, 4.510, 4.637, 4.981, 5.309, 5.515, 5.932, 6.082, 6.287, 6.612, 6.909, 7.164, 7.403, 7.633}, // gwt_100
# 	std::vector<double>{93.738, 94.878, 96.095, 97.909, 99.776, 103.357, 106.782, 110.947, 114.865, 120.030, 125.026, 130.127, 132.256, 133.904, 139.693, 145.821, 149.793, 160.062, 164.048, 170.253, 180.198, 190.144, 200.310, 210.204, 220.007}, uncor_1),
# 	lin(std::vector<double>{-1.004, -0.511, -0.001, 0.498, 0.996, 1.503, 2.002, 2.288, 2.497, 2.998, 3.303, 3.617, 4.022, 4.406, 4.614, 5.009, 5.088, 5.466, 5.703, 5.822, 6.013, 6.131, 6.310, 6.422, 6.506, 6.706, 6.920}, // gwt_110
# 	std::vector<double>{104.789, 105.825, 106.743, 108.350, 109.853, 113.369, 116.885, 119.584, 121.400, 125.851, 129.667, 133.496, 139.479, 145.502, 149.994, 158.224, 160.314, 170.129, 176.530, 180.178, 186.319, 190.266, 196.290, 200.276, 203.393, 210.248, 219.933}, uncor_1),
# 	lin(std::vector<double>{-1.003, -0.509, -0.002, 0.496, 1.002, 1.497, 1.698, 2.002, 2.235, 2.503, 3.003, 3.319, 3.709, 3.913, 4.015, 4.298, 4.516, 4.684, 4.770, 5.011, 5.210, 5.511, 5.601, 5.911, 6.155, 6.401}, // gwt_120
# 	std::vector<double>{112.893, 114.824, 116.963, 118.440, 119.865, 123.368, 124.782, 127.403, 129.960, 132.698, 138.084, 142.977, 148.961, 152.180, 154.283, 160.099, 164.422, 167.979, 170.043, 175.625, 180.286, 188.166, 190.373, 200.461, 210.381, 220.028}, uncor_1),
# 	lin(std::vector<double>{-1.003, -0.511, 0.001, 0.494, 0.989, 1.101, 1.503, 2.004, 2.086, 2.151, 2.495, 3.034, 3.418, 3.563, 3.801, 4.005, 4.507, 4.796, 4.860, 5.168, 5.447, 5.603, 5.676}, // gwt_130
# 	std::vector<double>{121.970, 123.901, 125.638, 127.881, 129.994, 130.929, 134.069, 138.182, 138.960, 139.895, 143.749, 150.485, 157.339, 160.169, 164.284, 168.815, 180.252, 187.950, 190.210, 200.272, 210.321, 216.450, 220.058}, uncor_1),
# 	lin(std::vector<double>{-1.003, -0.512, -0.001, 0.496, 0.965, 1.498, 1.994, 2.498, 2.804, 3.187, 3.447, 3.879, 4.002, 4.297, 4.641, 4.951, 5.198}, // gwt_140
# 	std::vector<double>{130.073, 132.057, 134.144, 137.140, 139.851, 144.522, 148.947, 154.566, 159.083, 165.093, 170.013, 179.919, 182.229, 190.110, 200.418, 210.389, 220.024}, uncor_1),
# 	lin(std::vector<double>{-1.002, -0.516, -0.002, 0.192, 0.492, 0.942, 1.001, 1.499, 1.962, 2.003, 2.508, 2.907, 3.232, 3.390, 3.506, 3.711, 3.891, 4.085, 4.418, 4.552, 4.699}, // gwt_150
# 	std::vector<double>{139.111, 141.212, 143.416, 144.193, 146.425, 149.811, 150.187, 155.093, 159.894, 160.271, 167.189, 173.952, 180.144, 182.779, 185.583, 190.243, 194.631, 200.266, 210.276, 214.639, 220.027}, uncor_1),
# 	lin(std::vector<double>{-1.002, -0.509, 0.005, 0.200, 0.499, 0.719, 0.985, 1.502, 1.772, 1.815, 2.002, 2.202, 2.573, 2.919, 3.003, 3.206, 3.421, 3.604, 3.819, 4.001, 4.167}, // gwt_160
# 	std::vector<double>{150.097, 151.808, 153.415, 154.245, 156.463, 158.098, 160.148, 166.131, 169.934, 170.440, 173.296, 177.060, 183.564, 190.093, 191.703, 195.273, 200.374, 204.477, 210.189, 215.201, 220.187}, uncor_1),
# 	lin(std::vector<double>{-1.002, -0.508, 0.004, 0.186, 0.498, 0.935, 1.021, 1.502, 1.591, 1.694, 1.956, 2.313, 2.506, 2.701, 3.006, 3.181, 3.566}, // gwt_170
# 	std::vector<double>{160.161, 161.807, 163.531, 164.192, 166.462, 169.810, 170.445, 177.000, 178.311, 180.323, 185.295, 192.513, 196.485, 200.418, 206.430, 210.376, 220.191}, uncor_1),
# 	lin(std::vector<double>{-1.000, -0.505, -0.004, 0.288, 0.496, 1.015, 1.531, 1.689, 2.036, 2.229, 2.411, 2.506, 2.758}, // gwt_180
# 	std::vector<double>{169.213, 171.118, 173.101, 174.138, 175.942, 180.354, 189.531, 192.777, 200.566, 205.085, 210.394, 212.939, 220.053}, uncor_1),
# }, gwt);

# %%
DIG_FILE_NAME = "3-eng-50-flaps-climb-wind-corr.dig"
INPUT = "horz_dist_brake_release_ft_1000s"
OUTPUT = "horz_obs_dist_1000s_ft_adj"
INTERP_VAL = "h_t_wnd"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_3, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto horz_obs_dist_1000s_ft_adj = linear_interpolate( scale_vals_3, {
# 	lin(std::vector<double>{-0.017, 4.812, 6.366, 9.862, 11.784, 14.916, 16.846, 19.410, 24.779, 28.071, 29.981, 31.306, 34.860, 36.728, 40.028, 45.087, 50.092, 55.183, 60.147, 65.206, 67.553, 70.072}, // tailwind_40
# 	std::vector<double>{-0.085, 3.527, 4.800, 7.502, 8.903, 11.184, 12.656, 14.771, 19.385, 21.979, 23.711, 24.970, 28.235, 29.915, 32.542, 36.683, 40.838, 44.946, 49.011, 53.190, 55.069, 57.142}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.026, 4.738, 9.842, 14.885, 19.948, 24.868, 26.475, 27.501, 33.047, 38.465, 43.962, 49.548, 55.036, 60.132, 65.207, 70.065}, // tailwind_20
# 	std::vector<double>{-0.028, 4.104, 8.808, 13.427, 18.031, 22.546, 24.004, 24.960, 30.004, 34.955, 39.952, 45.082, 50.046, 54.694, 59.265, 63.671}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.082, 4.764, 9.852, 14.854, 19.933, 24.886, 29.871, 34.963, 39.945, 44.975, 50.014, 55.122, 59.973, 65.171, 69.968}, // calm
# 	std::vector<double>{-0.047, 4.818, 9.882, 14.893, 19.924, 24.935, 29.909, 34.987, 39.951, 45.058, 50.027, 55.133, 60.040, 65.203, 69.978}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.013, 4.445, 7.840, 13.550, 18.102, 19.931, 22.794, 24.982, 30.009, 32.046, 35.035, 40.029, 45.060, 50.091, 55.102, 58.006, 59.801, 64.153}, // headwind_20
# 	std::vector<double>{0.024, 5.045, 8.694, 14.907, 19.819, 21.807, 24.930, 27.325, 32.734, 34.944, 38.190, 43.566, 49.112, 54.493, 60.063, 63.196, 65.202, 70.020}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.025, 3.754, 7.796, 12.446, 16.807, 21.020, 24.881, 29.659, 31.794, 33.893, 38.233, 40.576, 42.487, 46.724, 50.099, 55.126, 59.266}, // headwind_40
# 	std::vector<double>{0.119, 4.851, 9.446, 14.879, 19.942, 24.864, 29.393, 34.967, 37.395, 39.974, 45.070, 47.777, 50.049, 55.046, 59.097, 65.083, 70.014}, horz_dist_brake_release_ft_1000s),
# }, h_t_wnd);

# %%
DIG_FILE_NAME1 = "3-eng-50-flaps-climb-path-p2.dig"
DIG_FILE_NAME2 = "3-eng-50-flaps-climb-path-p1.dig"
INPUT = "horz_dist_brake_release_ft_1000s_adj"
OUTPUT = "vert_dist_1000s"
INTERP_VAL = "climb_factor"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME1}')
chart2 = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME2}')
i = 0
print(f"auto {OUTPUT} = linear_interpolate( scale_vals_4, {{")
for c, d in zip(chart.curveNames(), chart2.curveNames()):
    xVector = [row [0] for row in chart.curve(c)]
    xVector2 = [row [0] for row in chart2.curve(c)]
    xVector = xVector + xVector2

    yVector = [row [1]/10.0 for row in chart.curve(c)]
    yVector2 = [row [1] for row in chart2.curve(c)]
    yVector = yVector + yVector2
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f