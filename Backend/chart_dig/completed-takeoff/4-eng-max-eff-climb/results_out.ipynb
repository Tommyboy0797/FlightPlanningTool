# %%
import os
os.chdir("../..")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\mcdel\digitized-charts

# %%
TOP_FOLDER = "completed-takeoff/4-eng-max-eff-climb"

# %%
DIG_FILE_NAME = "4-eng-max-eff-climb-factor-temp-dev.dig"
INPUT = "t_dev"
OUTPUT = "uncor_1" 
INTERP_VAL = "tof"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_1, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto uncor_1 = linear_interpolate( scale_vals_1, {
# 	lin(std::vector<double>{-44.858, -0.789, 12.089, 27.671, 39.187, 44.605}, // factor__1
# 	std::vector<double>{-1.013, -1.029, -0.934, -0.695, -0.467, -0.322}, t_dev),
# 	lin(std::vector<double>{-44.904, -0.157, 10.687, 24.917, 34.400, 45.238}, // factor_0
# 	std::vector<double>{-0.002, 0.003, 0.077, 0.254, 0.461, 0.669}, t_dev),
# 	lin(std::vector<double>{-45.627, -2.236, 9.965, 20.807, 30.290, 35.709, 45.869}, // factor_1
# 	std::vector<double>{0.999, 1.004, 1.067, 1.203, 1.379, 1.504, 1.711}, t_dev),
# 	lin(std::vector<double>{-44.993, 0.430, 11.953, 20.761, 30.245, 41.084, 44.469}, // factor_2
# 	std::vector<double>{1.990, 2.026, 2.089, 2.214, 2.390, 2.598, 2.702}, t_dev),
# 	lin(std::vector<double>{-45.716, 1.065, 14.619, 27.489, 38.329, 44.425}, // factor_3
# 	std::vector<double>{3.001, 2.996, 3.111, 3.370, 3.537, 3.692}, t_dev),
# 	lin(std::vector<double>{-46.439, -1.693, 17.963, 27.444, 33.540, 45.057}, // factor_4
# 	std::vector<double>{3.992, 4.028, 4.154, 4.371, 4.506, 4.704}, t_dev),
# 	lin(std::vector<double>{-47.163, 0.295, 17.239, 30.787, 45.690}, // factor_5
# 	std::vector<double>{5.023, 5.039, 5.175, 5.435, 5.705}, t_dev),
# 	lin(std::vector<double>{-45.175, -0.427, 17.869, 35.483, 45.644}, // factor_6
# 	std::vector<double>{6.045, 6.030, 6.248, 6.550, 6.737}, t_dev),
# 	lin(std::vector<double>{-45.896, 3.596, 27.988, 38.145, 45.599}, // factor_7
# 	std::vector<double>{7.015, 7.021, 7.364, 7.654, 7.737}, t_dev),
# }, tof);

# %%
DIG_FILE_NAME = "4-eng-max-eff-climb-factor.dig"
INPUT = "uncor_1"
OUTPUT = "climb_factor"
INTERP_VAL = "gwt"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_2, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto climb_factor = linear_interpolate( scale_vals_2, {
# 	lin(std::vector<double>{-1.006, -0.512, -0.003, 0.491, 0.985, 1.498, 2.000, 2.505, 3.000, 3.510, 4.003, 4.396, 5.018, 5.518, 6.021, 6.427, 6.858, 7.322, 7.524, 7.855, 8.004}, // gwt_80
# 	std::vector<double>{75.945, 76.774, 77.849, 78.756, 79.702, 81.762, 83.834, 86.917, 90.065, 95.079, 99.820, 104.626, 111.932, 118.811, 126.053, 132.024, 139.862, 148.114, 152.492, 159.980, 163.503}, uncor_1),
# 	lin(std::vector<double>{-1.005, -0.511, -0.001, 0.496, 0.993, 1.497, 2.002, 2.500, 3.010, 3.104, 3.511, 3.804, 4.000, 4.126, 4.410, 5.016, 5.207, 5.515, 5.821, 6.023, 6.400, 6.521, 6.906, 7.389, 7.816, 8.004}, // gwt_90
# 	std::vector<double>{82.966, 84.417, 85.855, 87.850, 89.923, 92.824, 95.869, 99.302, 102.903, 103.875, 107.826, 110.844, 112.774, 114.549, 118.526, 127.076, 130.094, 135.095, 139.901, 143.113, 149.966, 152.142, 159.941, 170.149, 179.981, 185.020}, uncor_1),
# 	lin(std::vector<double>{-1.005, -0.509, -0.008, 0.495, 0.996, 1.502, 2.003, 2.497, 3.011, 3.523, 3.799, 4.204, 4.520, 4.880, 5.422, 6.027, 6.498, 6.921, 7.336, 7.714, 8.005}, // gwt_100
# 	std::vector<double>{92.254, 93.886, 95.596, 97.721, 99.871, 102.929, 105.960, 109.872, 113.979, 119.601, 122.658, 128.125, 133.669, 139.797, 149.720, 161.094, 170.395, 180.227, 190.163, 200.229, 207.924}, uncor_1),
# 	lin(std::vector<double>{-1.006, -0.507, -0.004, 0.496, 0.995, 1.505, 2.003, 2.356, 2.500, 3.011, 3.330, 3.496, 3.902, 4.513, 5.016, 5.255, 5.517, 5.724, 6.028, 6.532, 6.890, 7.104, 7.564}, // gwt_110
# 	std::vector<double>{101.633, 103.421, 105.092, 107.514, 110.002, 113.214, 116.570, 119.653, 121.039, 125.456, 129.913, 132.270, 137.685, 147.220, 155.186, 160.226, 165.615, 170.175, 176.535, 188.531, 198.143, 204.192, 220.049}, uncor_1),
# 	lin(std::vector<double>{-1.007, -0.514, -0.001, 0.494, 0.995, 1.501, 2.010, 2.294, 2.503, 3.008, 3.216, 3.614, 4.008, 4.436, 4.981, 5.212, 5.360, 5.529, 5.705, 6.054, 6.218, 6.311, 6.560}, // gwt_120
# 	std::vector<double>{112.174, 113.810, 115.352, 117.580, 119.808, 123.500, 127.075, 129.848, 132.024, 136.908, 140.004, 145.820, 151.676, 160.031, 170.511, 176.211, 180.149, 184.722, 190.189, 200.358, 206.305, 210.398, 220.022}, uncor_1),
# 	lin(std::vector<double>{-1.004, -0.506, -0.001, 0.499, 0.994, 1.501, 2.005, 2.500, 2.988, 3.382, 3.840, 4.016, 4.406, 4.516, 4.711, 4.845, 5.017, 5.182, 5.304, 5.458, 5.699, 5.908}, // gwt_130
# 	std::vector<double>{120.831, 122.813, 124.705, 127.438, 129.925, 133.630, 137.283, 142.076, 146.610, 152.686, 160.057, 162.738, 169.980, 171.988, 176.250, 179.916, 184.929, 190.189, 193.751, 200.099, 210.384, 220.049}, uncor_1),
# 	lin(std::vector<double>{-1.005, -0.509, 0.002, 0.495, 0.990, 1.500, 2.004, 2.502, 2.706, 3.128, 3.512, 3.705, 4.007, 4.195, 4.523, 4.621, 4.822, 4.946, 5.115, 5.212, 5.405}, // gwt_140
# 	std::vector<double>{131.842, 133.513, 135.197, 137.620, 140.081, 143.993, 148.152, 153.139, 155.199, 160.174, 166.275, 170.097, 176.250, 180.058, 188.090, 190.694, 196.458, 200.293, 206.408, 210.435, 220.009}, uncor_1),
# 	lin(std::vector<double>{-1.005, -0.509, -0.004, 0.496, 1.000, 1.502, 1.997, 2.446, 2.870, 3.011, 3.304, 3.565, 3.761, 3.976, 4.126, 4.521, 4.613, 4.903}, // gwt_150
# 	std::vector<double>{140.975, 142.918, 144.861, 147.478, 150.017, 153.696, 157.129, 162.531, 167.544, 169.241, 174.073, 179.994, 184.217, 190.111, 194.010, 205.695, 208.350, 219.918}, uncor_1),
# 	lin(std::vector<double>{-1.005, -0.510, -0.001, 0.498, 0.996, 1.506, 2.008, 2.121, 2.551, 2.907, 3.016, 3.491, 3.788, 3.899, 4.017, 4.120, 4.208, 4.472}, // gwt_160
# 	std::vector<double>{149.576, 151.714, 154.240, 157.194, 160.186, 164.824, 169.151, 170.679, 175.602, 179.864, 181.198, 190.046, 196.743, 199.528, 203.376, 206.512, 210.151, 220.073}, uncor_1),
# 	lin(std::vector<double>{-1.002, -0.508, -0.001, 0.495, 0.997, 1.503, 1.904, 2.320, 2.841, 2.909, 3.303, 3.513, 3.698, 4.008}, // gwt_170
# 	std::vector<double>{159.862, 161.999, 164.228, 167.078, 170.303, 174.669, 178.374, 183.219, 190.098, 190.758, 198.363, 203.829, 208.533, 220.320}, uncor_1),
# 	lin(std::vector<double>{-1.003, -0.003, 0.500, 0.999, 1.504, 1.591, 2.024, 2.503, 2.718, 2.893, 3.012, 3.202, 3.548}, // gwt_180
# 	std::vector<double>{170.200, 174.423, 177.299, 180.252, 185.291, 186.172, 190.616, 196.367, 200.202, 203.052, 205.927, 210.332, 220.139}, uncor_1),
# }, gwt);

# %%
DIG_FILE_NAME = "4-eng-max-eff-climb-wind-corr.dig"
INPUT = "horz_dist_brake_release_ft_1000s"
OUTPUT = "horz_dist_brake_release_ft_1000s_adj"
INTERP_VAL = "h_t_wnd"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')

print(f"auto {OUTPUT} = linear_interpolate( scale_vals_3, {{")
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, {INPUT}),")
print(f"}}, {INTERP_VAL});")
# Out:
# auto horz_dist_brake_release_ft_1000s_adj = linear_interpolate( scale_vals_3, {
# 	lin(std::vector<double>{0.223, 4.945, 9.986, 18.336, 25.052, 30.097, 35.073, 40.118, 45.191, 53.255, 60.216, 65.351, 70.021}, // tail_40
# 	std::vector<double>{-0.038, 3.882, 7.965, 14.850, 20.380, 24.540, 28.692, 32.891, 37.124, 43.888, 49.741, 54.123, 58.048}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{0.088, 5.243, 9.942, 14.954, 20.048, 25.028, 30.086, 35.119, 38.848, 44.339, 49.928, 55.214, 60.267, 65.349, 70.006}, // tail_20
# 	std::vector<double>{-0.048, 4.571, 8.833, 13.336, 17.906, 22.443, 26.994, 31.598, 34.949, 40.011, 45.058, 49.894, 54.527, 59.150, 63.446}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.002, 4.802, 9.975, 14.922, 19.829, 24.993, 30.066, 35.059, 40.100, 45.117, 50.109, 55.199, 60.196, 65.258, 69.972}, // calm
# 	std::vector<double>{-0.009, 4.788, 9.941, 14.907, 19.810, 24.973, 30.045, 35.044, 40.029, 45.091, 50.071, 55.119, 60.157, 65.214, 69.914}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.014, 4.067, 8.684, 13.113, 17.689, 25.030, 31.138, 35.632, 40.118, 44.739, 50.173, 55.226, 60.268, 62.817}, // head_20
# 	std::vector<double>{0.020, 4.706, 9.869, 14.854, 19.954, 28.236, 34.976, 40.018, 45.037, 50.094, 56.096, 61.630, 67.204, 69.975}, horz_dist_brake_release_ft_1000s),
# 	lin(std::vector<double>{-0.039, 4.877, 9.960, 14.977, 20.022, 24.983, 30.180, 35.075, 39.144, 45.126, 50.155, 55.323}, // head_40
# 	std::vector<double>{0.121, 6.634, 13.166, 19.674, 26.110, 32.372, 38.957, 45.074, 50.074, 57.507, 63.659, 69.984}, horz_dist_brake_release_ft_1000s),
# }, h_t_wnd);

# %%
DIG_FILE_NAME1 = "4-eng-max-eff-climb-path-p2.dig"
DIG_FILE_NAME2 = "4-eng-max-eff-climb-path-p1.dig"
INPUT = "horz_dist_brake_release_ft_1000s_adj"
OUTPUT = "vert_dist_1000s"
INTERP_VAL = "climb_factor"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME1}')
chart2 = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME2}')
i = 0
print(f"auto {OUTPUT} = linear_interpolate( scale_vals_4, {{")
for c, d in zip(chart.curveNames(), chart2.curveNames()):
    xVector = [row [0] for row in chart.curve(c)]
    xVector2 = [row [0] for row in chart2.curve(c)]
    xVector = xVector + xVector2

    yVector = [row [1]/10.0 for row in chart.curve(c)]
    yVector2 = [row [1] for row in chart2.curve(c)]
    yVector = yVector + yVector2

    c_clean = c.replace("-", "_")

    print(f"\tlin(std::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in xVector]) + f"}}, // {c_clean.lower()}")
    print(f"\tstd::vector<double>{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + f"}}, {INPUT}),")
    i+=1
print(f"}}, {INTERP_VAL});")
print(i)
# Out:
# auto vert_dist_1000s = linear_interpolate( scale_vals_4, {
# 	lin(std::vector<double>{0.637, 1.644, 1.881, 2.469, 3.120, 3.468, 4.875, 6.001, 6.669, 7.712, 8.771, 9.250, 9.577, 9.219, 12.004, 13.360, 16.261, 19.192, 21.196, 23.640, 25.039}, // factor_80
# 	std::vector<double>{0.000, 0.398, 0.498, 0.748, 1.001, 1.147, 1.391, 1.596, 1.757, 2.008, 2.255, 2.364, 2.500, 2.502, 3.501, 3.999, 5.008, 6.016, 6.717, 7.520, 8.005}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{0.669, 1.810, 2.948, 3.526, 4.890, 6.349, 6.987, 8.257, 9.676, 10.444, 11.215, 10.897, 12.486, 14.237, 15.745, 17.542, 19.235, 22.680, 24.664, 26.170, 29.649}, // factor_90
# 	std::vector<double>{-0.000, 0.380, 0.749, 0.956, 1.150, 1.383, 1.503, 1.757, 2.032, 2.256, 2.500, 2.504, 3.004, 3.505, 4.005, 4.508, 5.009, 6.018, 6.573, 7.012, 8.003}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{0.720, 1.807, 2.620, 3.509, 3.750, 5.209, 7.091, 8.652, 10.301, 11.344, 12.533, 13.177, 12.846, 16.742, 20.720, 22.784, 26.878, 28.242, 33.280, 35.378}, // factor_100
# 	std::vector<double>{0.001, 0.271, 0.497, 0.750, 0.824, 1.001, 1.254, 1.504, 1.755, 2.006, 2.331, 2.500, 2.506, 3.501, 4.507, 5.010, 6.018, 6.335, 7.518, 8.002}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{1.013, 2.103, 3.170, 3.980, 4.514, 6.688, 7.527, 8.815, 10.887, 11.188, 12.148, 13.219, 14.337, 14.637, 15.412, 15.107, 19.792, 24.524, 29.302, 32.367, 36.690, 41.653}, // factor_110
# 	std::vector<double>{0.001, 0.247, 0.499, 0.688, 0.751, 1.002, 1.097, 1.253, 1.503, 1.546, 1.755, 2.004, 2.257, 2.321, 2.500, 2.505, 3.506, 4.508, 5.516, 6.153, 7.017, 8.003}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{1.230, 1.697, 2.681, 3.918, 4.396, 6.041, 8.030, 9.912, 11.802, 12.825, 14.110, 15.414, 16.691, 16.928, 18.003, 17.682, 23.086, 28.607, 34.243, 36.816, 42.871, 48.763}, // factor_120
# 	std::vector<double>{0.000, 0.050, 0.250, 0.496, 0.584, 0.749, 0.944, 1.125, 1.302, 1.506, 1.756, 2.004, 2.256, 2.304, 2.502, 2.505, 3.507, 4.509, 5.513, 5.966, 7.014, 8.004}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{1.475, 2.136, 3.294, 4.689, 5.025, 8.042, 8.509, 10.850, 12.115, 12.997, 13.483, 14.961, 16.475, 17.954, 19.464, 19.614, 20.974, 20.651, 26.937, 33.339, 39.903, 46.618, 49.969, 56.707}, // factor_130
# 	std::vector<double>{0.000, 0.046, 0.248, 0.486, 0.520, 0.774, 0.814, 1.001, 1.103, 1.169, 1.253, 1.504, 1.756, 2.006, 2.256, 2.278, 2.500, 2.508, 3.503, 4.507, 5.511, 6.519, 7.011, 8.003}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{1.717, 2.567, 3.903, 5.089, 6.121, 9.024, 12.709, 14.928, 15.694, 17.410, 19.126, 19.928, 20.845, 22.577, 24.348, 24.096, 31.344, 38.708, 42.408, 46.759, 53.971, 61.869, 65.684}, // factor_140
# 	std::vector<double>{-0.001, 0.047, 0.248, 0.426, 0.499, 0.719, 0.977, 1.141, 1.252, 1.503, 1.755, 1.872, 2.006, 2.255, 2.500, 2.507, 3.506, 4.512, 5.008, 5.576, 6.518, 7.523, 8.005}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{2.033, 2.967, 4.576, 5.548, 7.608, 9.906, 14.355, 15.221, 17.250, 18.135, 20.132, 22.120, 24.101, 25.678, 28.090, 27.772, 36.064, 44.623, 51.682, 62.147, 71.252, 75.751}, // factor_150
# 	std::vector<double>{-0.001, 0.046, 0.248, 0.370, 0.501, 0.652, 0.943, 1.002, 1.136, 1.253, 1.502, 1.754, 2.004, 2.201, 2.500, 2.508, 3.505, 4.512, 5.334, 6.517, 7.523, 8.004}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{2.326, 3.473, 5.339, 5.956, 9.226, 11.829, 13.640, 16.570, 20.236, 23.598, 25.870, 28.111, 29.396, 32.714, 32.469, 42.095, 46.839, 49.571, 57.162, 66.880, 74.912, 82.455, 87.546}, // factor_160
# 	std::vector<double>{0.001, 0.045, 0.249, 0.312, 0.498, 0.645, 0.749, 0.918, 1.128, 1.504, 1.756, 2.006, 2.151, 2.500, 2.506, 3.509, 4.006, 4.286, 5.058, 6.027, 6.796, 7.526, 8.003}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{2.753, 4.054, 6.403, 9.955, 13.565, 18.252, 21.277, 23.828, 25.065, 27.703, 30.059, 32.823, 33.491, 38.090, 37.909, 48.741, 59.886, 63.256, 67.928, 71.473, 77.306, 83.221, 89.124, 100.070, 101.197}, // factor_170
# 	std::vector<double>{-0.000, 0.046, 0.259, 0.434, 0.615, 0.849, 1.001, 1.128, 1.249, 1.506, 1.735, 2.005, 2.072, 2.500, 2.509, 3.508, 4.512, 4.803, 5.223, 5.522, 6.020, 6.525, 7.017, 7.923, 8.003}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{3.176, 4.826, 6.866, 9.983, 14.962, 19.383, 22.377, 28.108, 30.030, 32.398, 35.300, 37.839, 40.069, 41.299, 44.261, 44.114, 56.616, 69.164, 82.514, 96.141, 110.001, 116.669}, // factor_180
# 	std::vector<double>{0.002, 0.049, 0.213, 0.346, 0.558, 0.752, 0.884, 1.142, 1.307, 1.505, 1.756, 1.969, 2.159, 2.258, 2.499, 2.508, 3.508, 4.491, 5.518, 6.519, 7.526, 8.007}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{3.722, 5.510, 7.396, 14.954, 18.292, 22.936, 29.370, 33.408, 37.995, 41.345, 42.503, 48.115, 50.060, 51.586, 51.386, 65.883, 76.338, 88.116, 103.611, 118.954, 127.189, 134.843}, // factor_190
# 	std::vector<double>{0.001, 0.044, 0.171, 0.448, 0.572, 0.749, 1.001, 1.163, 1.505, 1.755, 1.842, 2.259, 2.392, 2.501, 2.509, 3.508, 4.235, 5.017, 6.027, 7.016, 7.528, 8.006}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{4.114, 6.436, 7.942, 14.963, 21.465, 27.188, 34.560, 39.840, 44.700, 47.207, 52.388, 55.061, 60.000, 60.165, 68.493, 83.684, 100.035, 105.494, 111.045, 120.021, 125.189, 137.905, 150.342, 156.438}, // factor_200
# 	std::vector<double>{-0.000, 0.044, 0.132, 0.353, 0.556, 0.750, 1.004, 1.189, 1.505, 1.669, 2.006, 2.178, 2.482, 2.494, 3.010, 3.934, 4.886, 5.211, 5.517, 6.024, 6.307, 7.018, 7.682, 8.008}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{4.901, 7.488, 8.536, 14.303, 23.514, 25.464, 32.303, 36.206, 40.652, 47.486, 50.037, 52.244, 54.411, 60.015, 59.966, 74.958, 89.589, 91.064, 109.178, 119.175, 139.483, 160.532, 174.989}, // factor_210
# 	std::vector<double>{0.001, 0.045, 0.097, 0.251, 0.497, 0.550, 0.752, 0.865, 1.003, 1.213, 1.356, 1.482, 1.604, 1.921, 1.927, 2.744, 3.512, 3.588, 4.520, 5.021, 6.021, 7.019, 7.695}, horz_dist_brake_release_ft_1000s_adj),
# 	lin(std::vector<double>{5.344, 8.777, 9.205, 14.979, 20.022, 30.053, 35.060, 40.111, 45.122, 55.113, 57.328, 60.010, 59.966, 75.071, 94.124, 106.396, 125.099, 139.541, 150.407, 174.926}, // factor_220
# 	std::vector<double>{0.000, 0.043, 0.063, 0.192, 0.307, 0.534, 0.660, 0.787, 0.918, 1.191, 1.254, 1.384, 1.385, 2.123, 3.011, 3.570, 4.397, 5.021, 5.479, 6.504}, horz_dist_brake_release_ft_1000s_adj),
# }, climb_factor);
# 15
