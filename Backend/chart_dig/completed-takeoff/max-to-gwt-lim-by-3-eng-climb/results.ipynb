# %%
import os
os.chdir("../")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\mcdel\digitized-charts

# %%
TOP_FOLDER = "max-to-gwt-lim-by-3-eng-climb"

# %%
DIG_FILE_NAME = "takeoff-factor-step1.dig"
X_AXIS_NAME = "tof_1"
Y_NAME = "t_dev"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]

    c_clean = c.replace("-", "_")
    x_nm = X_AXIS_NAME + "_" + c_clean
    print(f"const std::vector<double>{x_nm}{{" + ", ".join([str(s) for s in xVector]) + "};")
    c_clean = c_clean + "_" + Y_NAME
    print(f"const std::vector<double>{c_clean}{{" + ", ".join([str(s) for s in yVector]) + "};")
    # print("\n")
# Out:
# const std::vector<double>tof_1_t_45{2.506530385473532, 2.7304595521769457, 2.909659326413454, 3.122441420546245, 3.2569118023158445, 3.3688058345753333, 3.491988041589872, 3.8616757648179387, 4.1080401788470216, 4.2535165310028, 4.298387025654144, 4.410422160098069, 4.533604367112611, 4.6679336466977706, 4.802404028467368, 5.09349783496336, 5.31756810385121, 5.474304410325155, 5.6534900743432175, 5.933338036739485, 6.23586112017497, 6.519998588978158, 6.91900734613248, 7.0982071203689845, 7.284447893608954};
# const std::vector<double>t_45_t_dev{0.6772663150422759, 0.658247448926108, 0.6427957433681064, 0.632098754339147, 0.6202127117907986, 0.6059500597521857, 0.5952515731747131, 0.5643481620587099, 0.5429526864522777, 0.5298790879330536, 0.5168039918653166, 0.5025413398267038, 0.4870896342687021, 0.4668832121816586, 0.4395439665267957, 0.3848684703140959, 0.3420790166497444, 0.31355221502400576, 0.2814597503886139, 0.23207659062115318, 0.18399480051156256, 0.1415093491953672, 0.08534079711512252, 0.06394532150869028, 0.03773672498120578};
# const std::vector<double>tof_1_t_40{2.1928602294674313, 2.338477683807646, 2.741747726932001, 2.8985122538428314, 3.0328415334279946, 3.156023740442535, 3.2231883802351184, 3.380094009330385, 3.5368585362412155, 3.7832229502703, 4.275951778328471, 4.343116418121051, 4.488733872461266, 4.57833375957952, 4.6679336466977706, 5.037480267741399, 5.351150423747502, 5.530307867328673, 5.720682934572684, 6.079068372827251, 6.168654149727059, 6.504632561092839, 6.975010803135998};
# const std::vector<double>t_40_t_dev{0.7438278538033241, 0.7307527577355869, 0.6998493466195839, 0.6843976410615823, 0.6772663150422759, 0.6665678284648032, 0.6558708394358436, 0.6416081873972307, 0.6285330913294936, 0.6059500597521857, 0.5500855100200972, 0.5417651304814021, 0.5251243714040117, 0.5096726658460101, 0.49303190676861985, 0.4300360310172249, 0.35990882924652345, 0.3278163646111316, 0.294534846456351, 0.2339155801952205, 0.21846387463721892, 0.1673540414341723, 0.10316911216338856};
# const std::vector<double>tof_1_t_30{1.5545139470690437, 2.1817131568968122, 2.6521478398137504, 3.1448766678719196, 3.973569797077424, 4.1080401788470216, 4.242369458432179, 4.611916079475808, 5.12708015485965, 5.31756810385121, 5.552700783999017, 6.336650410519171};
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]

    c_clean = c.replace("-", "_")
    x_nm = X_AXIS_NAME + "_" + c_clean
    print(f"const std::vector<double>{x_nm}{{" + ", ".join([str(s) for s in xVector]) + "};")
    c_clean = c_clean + "_" + Y_NAME
    print(f"const std::vector<double>{c_clean}{{" + ", ".join([str(s) for s in yVector]) + "};")
    # print("\n")
# Out:
# const std::vector<double>tof_1_gwt_80{-0.002579771868797459, 0.9988493758403643};
# const std::vector<double>gwt_80{7.4067048403475155, 19.440299559968402};
# const std::vector<double>tof_1_gwt_90{-0.0024148675742818038, 0.999023197219352};
# const std::vector<double>gwt_90{5.335806160442296, 17.25741848132686};
# const std::vector<double>tof_1_gwt_100{-0.0022499632797661484, 0.9979899555160374};
# const std::vector<double>gwt_100{3.264907480537069, 15.242511000789797};
# const std::vector<double>tof_1_gwt_110{-0.0021073460811381617, 0.9968928114020643};
# const std::vector<double>gwt_110{1.4738942795893166, 14.011198239873629};
# const std::vector<double>tof_1_gwt_120{-0.0019780988939257504, 0.9982127983984515};
# const std::vector<double>gwt_120{-0.14921584113730546, 12.444008800631835};
# const std::vector<double>tof_1_gwt_130{-0.0006774457317142712, 1.0006997272123093};
# const std::vector<double>gwt_130{-1.49251100078979, 11.212696039715667};
# const std::vector<double>tof_1_gwt_140{-0.0029727302282251122, 0.23455300600322238, 0.5126527262345492, 0.7418195824164527, 0.8564074662419943, 0.9149018092657353, 0.9984222712694499};
# const std::vector<double>gwt_140{-2.667903080221137, 0.18659031930498315, 3.6567048403475084, 6.455207040505464, 7.798502200157962, 8.414193839557711, 9.813409680695024};
# const std::vector<double>tof_1_gwt_150{-0.0016884003391412217, 0.09619954632567163, 0.19047668565511494, 0.3480407980683714, 0.4889005203939556, 0.6536134504439904, 0.7085237205399004, 0.7825302197921999, 0.8684841249488175, 0.9186106764538349, 0.9591430395236509, 0.998498038411};
# const std::vector<double>gwt_150{-3.7873039602843193, -2.7798149610741163, -1.436590319304969, 0.35449339952612746, 1.8656916393997562, 3.880599119936811, 4.49629075933656, 5.335806160442289, 6.17539207943134, 6.847004400315917, 7.9664052803790995, 8.861911880852979};
# const std::vector<double>tof_1_gwt_160{-0.0004011171883453457, 0.07002726734359077, 0.15835373503408584, 0.21923545296901525, 0.34695257103887034, 0.46990379345619193, 0.5964138540590371, 0.6537159576083716, 0.7181788008247124, 0.8112845285638641, 0.8972116993129431, 0.9449389482612518, 0.9974098057662064};
# const std::vector<double>gwt_160{-4.9626960397156665, -4.179101320094773, -3.115691639399742, -2.499999999999993, -0.988801760126357, 0.35449339952612746, 2.0335947196208934, 2.5932951596524845, 3.2649074805370617, 4.328387679115423, 5.503709240663433, 6.287303960284326, 7.518687239083825};
# const std::vector<double>tof_1_gwt_170{-0.0012001223578730347, 0.12663641633902273, 0.26499026518075725, 0.35823904357878045, 0.49133283352497337, 0.5725393677303688, 0.6387239808036674, 0.6800714652296713, 0.7394823159446169, 0.8146733433461872, 0.8846127347909489, 0.9079221217442104, 0.9229636964000176, 0.9349834794226906, 0.9559928308961689, 0.9792909872644531, 0.9965680215364232};
# const std::vector<double>gwt_170{-5.741495543269764, -4.331137876565492, -2.673967618187966, -1.6867172514949687, -0.13532381812026983, 0.8519265485727203, 1.4513285569220358, 2.0507305652713512, 2.6501325736206667, 3.5668650569784504, 4.272043890330586, 4.5541154236714405, 4.695151190341868, 4.977222723682722, 5.788178382037685, 6.211285682048967, 6.634392982060248};
# const std::vector<double>tof_1_gwt_175{-0.004129261664943817, 0.09362412772033735, 0.1883641484112173, 0.2838540017178921, 0.3846207597975745, 0.4793663957809431, 0.5756229275808789, 0.6718626135033485, 0.7688605549803461, 0.863600575671226, 0.9215033382158486, 0.9590539295767242, 0.9868370434085558, 0.9981098014616783};
# const std::vector<double>gwt_175{-6.764004851630368, -5.6357187182669435, -4.472173643235919, -3.2733696265372814, -2.180342434841471, -1.0873152431456532, -0.06480593478506336, 1.1692570235811814, 2.3328020986122056, 3.4963471736432368, 4.131008123660159, 5.153517432020756, 5.964473090375719, 6.17602674038136};

# %%
DIG_FILE_NAME = "takeoff gw limited by 3 eng climb-drag.dig"
X_AXIS_NAME = ""
Y_NAME = ""
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]

    c_clean = c.replace("-", "_")
    x_nm = X_AXIS_NAME + "_" + c_clean
    print(f"const std::vector<double>{x_nm}{{" + ", ".join([str(s) for s in xVector]) + "};")
    c_clean = c_clean + "_" + Y_NAME
    print(f"const std::vector<double>{c_clean}{{" + ", ".join([str(s) for s in yVector]) + "};")
    # print("\n")
# Out:
# const std::vector<double>_rate__5{1.2385786802028633, 301.2338930105425};
# const std::vector<double>rate__5_{-5.012288916592603, -9.05215795720423};
# const std::vector<double>_rate_0{-1.240140570090034, 299.9999999999998};
# const std::vector<double>rate_0_{-0.1312040894667703, -4.002518270421071};
# const std::vector<double>_rate_5{-1.240140570090034, 299.9999999999998};
# const std::vector<double>rate_5_{4.974797343261002, 1.0473522813676368};
# const std::vector<double>_rate_10{-1.240140570090034, 301.2338930105425};
# const std::vector<double>rate_10_{9.912476826976288, 6.714681307077484};
# const std::vector<double>_rate_15{-1.240140570090034, 299.9999999999998};
# const std::vector<double>rate_15_{14.906216497825937, 11.876582755738774};
# const std::vector<double>_rate_20{-2.2737367544323206e-13, 299.9999999999998};
# const std::vector<double>rate_20_{19.90018820261787, 17.150835443674325};
# const std::vector<double>_rate_25{-1.240140570090034, 299.9999999999998};
# const std::vector<double>rate_25_{24.949826720464287, 22.649611655366137};
