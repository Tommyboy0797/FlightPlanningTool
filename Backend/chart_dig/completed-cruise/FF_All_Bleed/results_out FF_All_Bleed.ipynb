# %%
import os
os.chdir("../")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\scott\Documents\GitHub\Charts\digitized-charts

# %%
TOP_FOLDER = "FF_All_Bleed"

# %%
DIG_FILE_NAME = "FF_All_Alt_Speed.dig"
X_AXIS_NAME = "KIAS"
Y_NAME = "alt"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto ff_a_ = lin({c_clean}_y, {x_nm}_x, alt_div_1000);")
    print("\n")
# Out:
# const std::vector<double>FF_All_Alt_Speed_20_x{1.358, 1.629, 2.071, 2.648, 3.361};
# const std::vector<double>FF_All_Alt_Speed_20_y{-0.084, 10.026, 20.049, 30.246, 40.357};
# auto ff_a_ = lin(FF_All_Alt_Speed_20_y, FF_All_Alt_Speed_20_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_40_x{2.919, 3.497, 4.345, 5.398, 6.959};
# const std::vector<double>FF_All_Alt_Speed_40_y{0.007, 9.943, 20.229, 30.340, 40.279};
# auto ff_a_ = lin(FF_All_Alt_Speed_40_y, FF_All_Alt_Speed_40_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_60_x{4.379, 5.330, 6.518, 8.215, 10.456};
# const std::vector<double>FF_All_Alt_Speed_60_y{-0.163, 10.035, 20.060, 30.434, 40.287};
# auto ff_a_ = lin(FF_All_Alt_Speed_60_y, FF_All_Alt_Speed_60_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_80_x{5.907, 7.197, 8.792, 10.863, 13.851};
# const std::vector<double>FF_All_Alt_Speed_80_y{-0.421, 10.040, 20.240, 30.267, 40.383};
# auto ff_a_ = lin(FF_All_Alt_Speed_80_y, FF_All_Alt_Speed_80_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_100_x{7.468, 8.996, 10.931, 13.681, 17.144};
# const std::vector<double>FF_All_Alt_Speed_100_y{-0.243, 10.044, 19.984, 30.361, 40.304};
# auto ff_a_ = lin(FF_All_Alt_Speed_100_y, FF_All_Alt_Speed_100_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_120_x{8.928, 10.897, 13.308, 16.566, 20.708};
# const std::vector<double>FF_All_Alt_Speed_120_y{-0.152, 10.049, 19.989, 30.455, 40.749};
# auto ff_a_ = lin(FF_All_Alt_Speed_120_y, FF_All_Alt_Speed_120_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_140_x{10.490, 12.561, 15.344, 19.112, 23.967};
# const std::vector<double>FF_All_Alt_Speed_140_y{-0.061, 9.792, 20.082, 30.374, 40.495};
# auto ff_a_ = lin(FF_All_Alt_Speed_140_y, FF_All_Alt_Speed_140_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_160_x{12.051, 14.496, 17.585, 21.896, 27.226};
# const std::vector<double>FF_All_Alt_Speed_160_y{-0.057, 9.971, 20.174, 30.468, 40.504};
# auto ff_a_ = lin(FF_All_Alt_Speed_160_y, FF_All_Alt_Speed_160_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_180_x{13.545, 13.545, 16.329, 19.791, 24.374, 30.417};
# const std::vector<double>FF_All_Alt_Speed_180_y{-0.053, -0.053, 10.062, 20.093, 30.039, 40.424};
# auto ff_a_ = lin(FF_All_Alt_Speed_180_y, FF_All_Alt_Speed_180_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_200_x{15.073, 18.094, 21.896, 26.988, 33.472};
# const std::vector<double>FF_All_Alt_Speed_200_y{-0.224, 10.067, 20.098, 30.220, 40.519};
# auto ff_a_ = lin(FF_All_Alt_Speed_200_y, FF_All_Alt_Speed_200_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_220_x{16.533, 20.029, 24.171, 29.704, 35.068};
# const std::vector<double>FF_All_Alt_Speed_220_y{-0.307, 10.246, 20.104, 30.314, 38.170};
# auto ff_a_ = lin(FF_All_Alt_Speed_220_y, FF_All_Alt_Speed_220_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_240_x{18.026, 21.591, 26.174, 32.352, 35.034};
# const std::vector<double>FF_All_Alt_Speed_240_y{-0.042, 10.163, 20.021, 30.494, 34.771};
# auto ff_a_ = lin(FF_All_Alt_Speed_240_y, FF_All_Alt_Speed_240_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_260_x{19.588, 23.424, 28.414, 34.661, 35.102};
# const std::vector<double>FF_All_Alt_Speed_260_y{-0.126, 9.993, 20.027, 30.239, 31.111};
# auto ff_a_ = lin(FF_All_Alt_Speed_260_y, FF_All_Alt_Speed_260_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_300_x{21.149, 25.257, 30.383, 35.000};
# const std::vector<double>FF_All_Alt_Speed_300_y{-0.209, 10.346, 19.684, 27.712};
# auto ff_a_ = lin(FF_All_Alt_Speed_300_y, FF_All_Alt_Speed_300_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_320_x{22.611, 27.102, 32.491, 35.036};
# const std::vector<double>FF_All_Alt_Speed_320_y{-0.181, 10.151, 19.936, 23.950};
# auto ff_a_ = lin(FF_All_Alt_Speed_320_y, FF_All_Alt_Speed_320_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_340_x{24.215, 28.920, 35.036};
# const std::vector<double>FF_All_Alt_Speed_340_y{-0.067, 9.991, 20.601};
# auto ff_a_ = lin(FF_All_Alt_Speed_340_y, FF_All_Alt_Speed_340_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_360_x{25.691, 30.674, 35.036};
# const std::vector<double>FF_All_Alt_Speed_360_y{-0.283, 10.160, 17.582};
# auto ff_a_ = lin(FF_All_Alt_Speed_360_y, FF_All_Alt_Speed_360_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_380_x{27.273, 32.385, 35.079};
# const std::vector<double>FF_All_Alt_Speed_380_y{-0.170, 10.109, 14.508};
# auto ff_a_ = lin(FF_All_Alt_Speed_380_y, FF_All_Alt_Speed_380_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_400_x{28.770, 34.031, 35.015};
# const std::vector<double>FF_All_Alt_Speed_400_y{-0.111, 10.168, 11.543};
# auto ff_a_ = lin(FF_All_Alt_Speed_400_y, FF_All_Alt_Speed_400_x, alt_div_1000);
#
#
# const std::vector<double>FF_All_Alt_Speed_420_x{30.225, 35.058};
# const std::vector<double>FF_All_Alt_Speed_420_y{-0.162, 8.853};
# auto ff_a_ = lin(FF_All_Alt_Speed_420_y, FF_All_Alt_Speed_420_x, alt_div_1000);

# %%
DIG_FILE_NAME = "FF_All_Alt_Temp.dig"
X_AXIS_NAME = "fuel_ref_a"
Y_NAME = "OAT"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto ff_ta_ = lin({x_nm}_x, {c_clean}_y, fflow_all_res);")
    print("\n")
# Out:
# const std::vector<double>FF_All_alt_temp__60_x{-0.085, 4.951, 9.902, 14.854, 19.976, 24.927, 30.049, 35.000};
# const std::vector<double>FF_All_alt_temp__60_y{30.978, 31.087, 31.630, 33.587, 36.304, 40.652, 47.174, 54.022};
# auto ff_ta_ = lin(FF_All_alt_temp__60_x, FF_All_alt_temp__60_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp__50_x{-0.085, 5.037, 9.817, 14.854, 19.890, 24.927, 30.049, 35.085};
# const std::vector<double>FF_All_alt_temp__50_y{32.174, 32.500, 33.152, 35.000, 38.043, 41.739, 46.848, 52.935};
# auto ff_ta_ = lin(FF_All_alt_temp__50_x, FF_All_alt_temp__50_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp__40_x{-0.085, 4.866, 9.860, 14.896, 19.762, 24.927, 30.049, 35.043};
# const std::vector<double>FF_All_alt_temp__40_y{32.065, 32.391, 33.098, 34.511, 37.228, 40.761, 44.728, 49.511};
# auto ff_ta_ = lin(FF_All_alt_temp__40_x, FF_All_alt_temp__40_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp__30_x{-0.171, 4.909, 9.860, 15.024, 19.933, 25.012, 30.049, 35.043};
# const std::vector<double>FF_All_alt_temp__30_y{31.141, 31.141, 31.848, 32.935, 35.163, 37.880, 41.304, 45.598};
# auto ff_ta_ = lin(FF_All_alt_temp__30_x, FF_All_alt_temp__30_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp__20_x{-0.085, 5.037, 9.945, 15.024, 19.933, 24.969, 30.091, 35.000};
# const std::vector<double>FF_All_alt_temp__20_y{28.750, 28.804, 29.293, 30.380, 32.228, 34.511, 37.228, 40.543};
# auto ff_ta_ = lin(FF_All_alt_temp__20_x, FF_All_alt_temp__20_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp__10_x{0.043, 5.037, 9.902, 14.939, 17.628, 19.805, 24.969, 29.963, 35.085};
# const std::vector<double>FF_All_alt_temp__10_y{23.804, 23.750, 24.239, 25.000, 28.043, 28.533, 30.544, 32.446, 35.380};
# auto ff_ta_ = lin(FF_All_alt_temp__10_x, FF_All_alt_temp__10_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_0_x{-0.128, 5.079, 9.817, 15.067, 19.933, 25.012, 27.402, 30.091, 34.957};
# const std::vector<double>FF_All_alt_temp_0_y{20.543, 20.707, 20.924, 21.848, 23.043, 24.456, 27.011, 28.043, 31.141};
# auto ff_ta_ = lin(FF_All_alt_temp_0_x, FF_All_alt_temp_0_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_10_x{-0.085, -0.085, 4.951, 9.860, 14.939, 19.933, 24.969, 29.878, 32.482, 35.128};
# const std::vector<double>FF_All_alt_temp_10_y{17.011, 17.011, 17.174, 17.391, 18.152, 19.456, 20.978, 22.880, 25.761, 27.446};
# auto ff_ta_ = lin(FF_All_alt_temp_10_x, FF_All_alt_temp_10_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_20_x{-0.043, 5.037, 9.945, 14.896, 19.933, 25.055, 30.049, 35.171};
# const std::vector<double>FF_All_alt_temp_20_y{13.859, 13.587, 14.022, 14.728, 15.924, 17.609, 19.565, 22.391};
# auto ff_ta_ = lin(FF_All_alt_temp_20_x, FF_All_alt_temp_20_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_30_x{-0.043, 4.994, 9.988, 14.854, 20.018, 24.841, 30.006, 35.085};
# const std::vector<double>FF_All_alt_temp_30_y{10.870, 10.543, 10.815, 11.685, 12.989, 14.402, 16.902, 20.489};
# auto ff_ta_ = lin(FF_All_alt_temp_30_x, FF_All_alt_temp_30_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_40_x{0.043, 4.909, 9.902, 14.854, 19.890, 24.927, 29.537, 35.000};
# const std::vector<double>FF_All_alt_temp_40_y{7.500, 7.554, 7.989, 8.696, 10.109, 12.446, 15.163, 21.304};
# auto ff_ta_ = lin(FF_All_alt_temp_40_x, FF_All_alt_temp_40_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_50_x{-0.085, 5.079, 9.860, 14.982, 19.933, 25.055, 29.963, 35.128};
# const std::vector<double>FF_All_alt_temp_50_y{5.109, 4.783, 5.435, 6.739, 8.424, 11.902, 16.196, 21.522};
# auto ff_ta_ = lin(FF_All_alt_temp_50_x, FF_All_alt_temp_50_y, fflow_all_res);
#
#
# const std::vector<double>FF_All_alt_temp_60_x{0.043, 4.994, 9.817, 9.817, 14.939, 19.890, 24.927, 30.049, 35.043};
# const std::vector<double>FF_All_alt_temp_60_y{3.424, 3.533, 4.402, 4.402, 5.870, 8.587, 12.228, 16.467, 21.956};
# auto ff_ta_ = lin(FF_All_alt_temp_60_x, FF_All_alt_temp_60_y, fflow_all_res);

# %%
DIG_FILE_NAME = "FF_All_Alt_FRN.dig"
X_AXIS_NAME = "fuel_ref"
Y_NAME = "altitude"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto ff_a_pxalt_ = lin({c_clean}_y, {x_nm}_x, fflow_all_res_2);")
    print("\n")
# Out:
# const std::vector<double>FF_All_Alt_0_x{13.761, 18.932, 22.991, 23.120, 23.291};
# const std::vector<double>FF_All_Alt_0_y{1.956, 10.109, 16.956, 30.054, 55.000};
# auto ff_a_pxalt_ = lin(FF_All_Alt_0_y, FF_All_Alt_0_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_5_x{9.829, 12.479, 15.043, 19.915, 22.008, 22.180, 22.222};
# const std::vector<double>FF_All_Alt_5_y{1.902, 5.706, 9.891, 20.054, 24.891, 33.098, 55.163};
# auto ff_a_pxalt_ = lin(FF_All_Alt_5_y, FF_All_Alt_5_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_10_x{7.521, 9.103, 12.521, 20.427, 20.812, 21.068};
# const std::vector<double>FF_All_Alt_10_y{2.609, 4.728, 11.630, 32.989, 42.065, 55.054};
# auto ff_a_pxalt_ = lin(FF_All_Alt_10_y, FF_All_Alt_10_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_15_x{5.470, 6.709, 10.470, 20.128, 20.385};
# const std::vector<double>FF_All_Alt_15_y{2.663, 5.054, 15.000, 49.185, 55.163};
# auto ff_a_pxalt_ = lin(FF_All_Alt_15_y, FF_All_Alt_15_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_20_x{4.402, 6.282, 12.521, 17.564};
# const std::vector<double>FF_All_Alt_20_y{2.717, 10.000, 34.837, 55.163};
# auto ff_a_pxalt_ = lin(FF_All_Alt_20_y, FF_All_Alt_20_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_25_x{4.188, 4.786, 6.538, 8.462, 13.675};
# const std::vector<double>FF_All_Alt_25_y{2.717, 10.054, 20.000, 30.000, 55.109};
# auto ff_a_pxalt_ = lin(FF_All_Alt_25_y, FF_All_Alt_25_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_30_x{3.932, 4.487, 6.239, 10.000};
# const std::vector<double>FF_All_Alt_30_y{2.717, 15.217, 29.891, 55.217};
# auto ff_a_pxalt_ = lin(FF_All_Alt_30_y, FF_All_Alt_30_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_35_x{3.803, 3.889, 4.359, 7.436};
# const std::vector<double>FF_All_Alt_35_y{2.446, 15.000, 24.837, 55.163};
# auto ff_a_pxalt_ = lin(FF_All_Alt_35_y, FF_All_Alt_35_x, fflow_all_res_2);
#
#
# const std::vector<double>FF_All_Alt_40_x{3.162, 3.248, 3.846, 5.427};
# const std::vector<double>FF_All_Alt_40_y{2.663, 15.054, 30.109, 55.109};
# auto ff_a_pxalt_ = lin(FF_All_Alt_40_y, FF_All_Alt_40_x, fflow_all_res_2);

# %%
DIG_FILE_NAME = "FF_All_FRN_PLA.dig"
X_AXIS_NAME = "fuel_ref"
Y_NAME = "fuel_flow"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto ff_a_fref_ = lin({x_nm}_x, {c_clean}_y, fflow_all_res_3);")
    print("\n")
# Out:
# const std::vector<double>FF_All_FRN_PLA_33_x{3.402, 4.931, 7.512, 9.895, 14.990, 17.817, 20.036, 22.584, 25.016};
# const std::vector<double>FF_All_FRN_PLA_33_y{2.674, 3.359, 4.099, 4.248, 4.437, 4.518, 4.778, 5.462, 6.202};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_33_x, FF_All_FRN_PLA_33_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_37_x{3.386, 4.947, 7.577, 14.974, 14.974, 17.127, 20.020, 22.485, 25.000};
# const std::vector<double>FF_All_FRN_PLA_37_y{2.852, 3.565, 4.359, 5.206, 5.206, 5.452, 6.109, 6.848, 7.972};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_37_x, FF_All_FRN_PLA_37_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_40_x{4.947, 4.947, 7.446, 12.130, 16.256, 19.987, 25.016};
# const std::vector<double>FF_All_FRN_PLA_40_y{3.661, 3.661, 4.538, 5.454, 6.152, 7.138, 9.426};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_40_x, FF_All_FRN_PLA_40_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_45_x{3.353, 4.964, 9.977, 14.990, 19.938, 25.049};
# const std::vector<double>FF_All_FRN_PLA_45_y{3.058, 3.825, 5.620, 6.811, 8.688, 11.471};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_45_x, FF_All_FRN_PLA_45_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_50_x{3.402, 5.424, 7.232, 9.977, 15.039, 17.439, 20.069, 22.567, 25.066};
# const std::vector<double>FF_All_FRN_PLA_50_y{3.181, 4.305, 5.073, 6.265, 8.060, 8.978, 10.211, 11.884, 13.694};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_50_x, FF_All_FRN_PLA_50_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_55_x{3.435, 7.298, 10.076, 15.007, 17.505, 21.302, 25.066};
# const std::vector<double>FF_All_FRN_PLA_55_y{3.236, 5.581, 6.910, 9.020, 10.418, 13.147, 16.013};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_55_x, FF_All_FRN_PLA_55_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_60_x{3.353, 7.396, 11.012, 15.253, 20.036, 25.049};
# const std::vector<double>FF_All_FRN_PLA_60_y{3.250, 6.061, 8.048, 10.557, 14.122, 18.304};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_60_x, FF_All_FRN_PLA_60_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_65_x{3.370, 7.429, 11.243, 12.508, 19.675, 25.099};
# const std::vector<double>FF_All_FRN_PLA_65_y{3.319, 6.513, 8.954, 9.831, 15.590, 20.746};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_65_x, FF_All_FRN_PLA_65_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_70_x{3.345, 9.977, 9.977, 14.990, 22.091, 25.033};
# const std::vector<double>FF_All_FRN_PLA_70_y{3.422, 8.817, 8.817, 13.233, 19.856, 22.914};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_70_x, FF_All_FRN_PLA_70_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_75_x{3.346, 9.961, 14.957, 20.661, 25.016};
# const std::vector<double>FF_All_FRN_PLA_75_y{3.385, 9.627, 14.523, 20.035, 24.218};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_75_x, FF_All_FRN_PLA_75_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_77.5_x{3.353, 9.928, 14.957, 25.033};
# const std::vector<double>FF_All_FRN_PLA_77.5_y{3.346, 9.942, 14.838, 24.726};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_77.5_x, FF_All_FRN_PLA_77.5_y, fflow_all_res_3);
#
#
# const std::vector<double>FF_All_FRN_PLA_85_x{3.338, 7.507, 13.087, 25.040};
# const std::vector<double>FF_All_FRN_PLA_85_y{3.426, 7.552, 13.138, 25.035};
# auto ff_a_fref_ = lin(FF_All_FRN_PLA_85_x, FF_All_FRN_PLA_85_y, fflow_all_res_3);
