# %%
import os
os.chdir("../")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\scott\Documents\GitHub\Charts\digitized-charts

# %%
TOP_FOLDER = "FF_Normal_Bleed"

# %%
DIG_FILE_NAME = "FF_Normal_Alt_Speed.dig"
X_AXIS_NAME = "KIAS"
Y_NAME = "alt"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print("\n")
# Out:
# const std::vector<double>FF_Normal_Alt_speed_20_x{1.268, 1.545, 1.983, 2.530, 3.265};
# const std::vector<double>FF_Normal_Alt_speed_20_y{-0.166, 10.042, 20.028, 30.125, 40.333};
#
#
# const std::vector<double>FF_Normal_Alt_speed_40_x{2.779, 3.461, 4.196, 5.337, 6.774};
# const std::vector<double>FF_Normal_Alt_speed_40_y{0.000, 10.153, 19.972, 30.291, 40.277};
#
#
# const std::vector<double>FF_Normal_Alt_speed_60_x{4.264, 5.242, 6.490, 8.116, 10.336};
# const std::vector<double>FF_Normal_Alt_speed_60_y{-0.166, 10.153, 20.083, 30.236, 40.277};
#
#
# const std::vector<double>FF_Normal_Alt_speed_80_x{5.802, 7.131, 8.703, 10.950, 13.844};
# const std::vector<double>FF_Normal_Alt_speed_80_y{-0.111, 10.097, 20.083, 30.291, 40.222};
#
#
# const std::vector<double>FF_Normal_Alt_speed_100_x{7.286, 8.912, 10.970, 13.621, 17.298};
# const std::vector<double>FF_Normal_Alt_speed_100_y{-0.222, 10.097, 20.139, 30.402, 40.499};
#
#
# ...

# %%
DIG_FILE_NAME = "FF_Normal_Alt_Temp.dig"
X_AXIS_NAME = "fuel_ref_a"
Y_NAME = "OAT"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print("\n")
# Out:
# const std::vector<double>FF_Norm_oat__60_x{-0.213, 4.879, 9.910, 14.909, 19.911, 25.120, 30.060, 32.985, 35.225};
# const std::vector<double>FF_Norm_oat__60_y{26.876, 27.120, 28.024, 29.900, 32.923, 37.232, 43.105, 44.182, 43.174};
#
#
# const std::vector<double>FF_Norm_oat__50_x{-0.215, 4.916, 9.948, 14.879, 20.017, 25.158, 30.063, 32.749, 35.123};
# const std::vector<double>FF_Norm_oat__50_y{28.370, 28.718, 29.726, 31.672, 34.834, 39.178, 44.286, 44.877, 43.140};
#
#
# const std::vector<double>FF_Norm_oat__40_x{-0.145, 4.851, 9.950, 14.846, 19.984, 25.088, 29.989, 32.543, 35.125};
# const std::vector<double>FF_Norm_oat__40_y{29.378, 29.865, 30.630, 31.950, 35.147, 38.344, 41.749, 44.112, 43.869};
#
#
# const std::vector<double>FF_Norm_oat__30_x{-0.217, 4.847, 9.878, 15.012, 19.943, 25.046, 30.048, 35.291};
# const std::vector<double>FF_Norm_oat__30_y{27.780, 28.267, 29.031, 30.178, 31.916, 34.626, 37.927, 42.306};
#
#
# ...

# %%
DIG_FILE_NAME = "FF_Normal_Alt_FRN.dig"
X_AXIS_NAME = "fuel_ref"
Y_NAME = "altitude"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto ff_pxalt_ = lin({c_clean}_y, {x_nm}_x, lin_test_res_2);")
    print("\n")
# Out:
# const std::vector<double>FF_Normal_press_alt_0_x{17.490, 20.568, 21.414, 21.651, 21.888};
# const std::vector<double>FF_Normal_press_alt_0_y{-0.035, 4.869, 6.329, 7.268, 45.000};
# auto ff_pxalt_ = lin(FF_Normal_press_alt_0_y, FF_Normal_press_alt_0_x, lin_test_res_2);
#
#
# const std::vector<double>FF_Normal_press_alt_5_x{13.802, 16.982, 18.944, 20.264, 20.501, 20.636};
# const std::vector<double>FF_Normal_press_alt_5_y{-0.035, 4.938, 9.390, 12.345, 17.944, 45.000};
# auto ff_pxalt_ = lin(FF_Normal_press_alt_5_y, FF_Normal_press_alt_5_x, lin_test_res_2);
#
#
# const std::vector<double>FF_Normal_press_alt_10_x{11.231, 13.735, 15.731, 20.027, 20.399};
# const std::vector<double>FF_Normal_press_alt_10_y{0.035, 4.903, 10.050, 22.048, 45.000};
# auto ff_pxalt_ = lin(FF_Normal_press_alt_10_y, FF_Normal_press_alt_10_x, lin_test_res_2);
#
#
# const std::vector<double>FF_Normal_press_alt_15_x{8.965, 10.893, 12.652, 15.629, 18.606, 19.418, 19.655};
# ...

# %%
DIG_FILE_NAME = "FF_Normal_FRN_PLA.dig"
X_AXIS_NAME = "fuel_ref"
Y_NAME = "fuel_flow"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto ff_fref_ = lin({x_nm}_x, {c_clean}_y, lin_test_res_3);")
    print("\n")
# Out:
# const std::vector<double>FF_Norm_PLA_33_x{4.913, 9.997, 14.976, 17.525, 18.812, 19.982, 22.228, 25.039};
# const std::vector<double>FF_Norm_PLA_33_y{3.415, 3.346, 3.320, 3.317, 3.631, 4.129, 6.027, 9.129};
# auto ff_fref_ = lin(FF_Norm_PLA_33_x, FF_Norm_PLA_33_y, lin_test_res_3);
#
#
# const std::vector<double>FF_Norm_PLA_37_x{4.887, 14.976, 17.315, 18.773, 20.034, 22.491, 25.039};
# const std::vector<double>FF_Norm_PLA_37_y{3.589, 4.177, 4.490, 4.803, 5.421, 7.655, 10.736};
# auto ff_fref_ = lin(FF_Norm_PLA_37_x, FF_Norm_PLA_37_y, lin_test_res_3);
#
#
# const std::vector<double>FF_Norm_PLA_40_x{4.874, 15.607, 17.472, 18.773, 20.060, 22.333, 25.026};
# const std::vector<double>FF_Norm_PLA_40_y{3.687, 4.980, 5.239, 5.661, 6.604, 8.741, 11.897};
# auto ff_fref_ = lin(FF_Norm_PLA_40_x, FF_Norm_PLA_40_y, lin_test_res_3);
#
#
# const std::vector<double>FF_Norm_PLA_45_x{4.874, 15.554, 17.998, 19.903, 22.438, 25.039};
# ...
