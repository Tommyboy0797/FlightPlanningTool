# %%
import os
os.chdir("../")
print(os.getcwd())
from py_utils import *
# Out:
# c:\Users\scott\Documents\GitHub\Charts\digitized-charts

# %%
TOP_FOLDER = "HP_All_Bleed"

# %%
DIG_FILE_NAME = "HP_All_Alt_Speed.dig"
X_AXIS_NAME = "KIAS"
Y_NAME = "alt"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto hp_a_ = lin({c_clean}_y, {x_nm}_x, alt_div_1000);")
    print("\n")
# Out:
# const std::vector<double>HP_All_Alt_Speed_20_x{1.327, 1.651, 2.108, 2.618, 3.341};
# const std::vector<double>HP_All_Alt_Speed_20_y{-0.162, 9.889, 20.012, 30.207, 40.186};
# auto hp_a_ = lin(HP_All_Alt_Speed_20_y, HP_All_Alt_Speed_20_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_40_x{2.921, 3.511, 4.341, 5.409, 6.849};
# const std::vector<double>HP_All_Alt_Speed_40_y{-0.161, 9.890, 20.085, 30.209, 40.332};
# auto hp_a_ = lin(HP_All_Alt_Speed_40_y, HP_All_Alt_Speed_40_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_60_x{4.436, 5.345, 6.573, 8.173, 10.464};
# const std::vector<double>HP_All_Alt_Speed_60_y{-0.088, 9.963, 20.087, 30.282, 40.406};
# auto hp_a_ = lin(HP_All_Alt_Speed_60_y, HP_All_Alt_Speed_60_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_80_x{5.924, 7.152, 8.779, 10.990, 14.052};
# const std::vector<double>HP_All_Alt_Speed_80_y{-0.232, 9.964, 20.160, 30.284, 40.697};
# auto hp_a_ = lin(HP_All_Alt_Speed_80_y, HP_All_Alt_Speed_80_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_100_x{7.439, 8.986, 11.038, 13.648, 17.215};
# const std::vector<double>HP_All_Alt_Speed_100_y{-0.086, 10.037, 20.089, 30.141, 40.410};
# auto hp_a_ = lin(HP_All_Alt_Speed_100_y, HP_All_Alt_Speed_100_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_120_x{9.007, 10.767, 13.191, 16.332, 20.483};
# const std::vector<double>HP_All_Alt_Speed_120_y{-0.085, 10.038, 20.090, 30.142, 40.122};
# auto hp_a_ = lin(HP_All_Alt_Speed_120_y, HP_All_Alt_Speed_120_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_140_x{10.496, 12.574, 15.397, 19.070, 23.992};
# const std::vector<double>HP_All_Alt_Speed_140_y{-0.157, 10.039, 20.091, 30.143, 40.630};
# auto hp_a_ = lin(HP_All_Alt_Speed_140_y, HP_All_Alt_Speed_140_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_160_x{12.037, 14.408, 17.549, 21.807, 27.234};
# const std::vector<double>HP_All_Alt_Speed_160_y{-0.084, 9.968, 20.092, 30.434, 40.487};
# auto hp_a_ = lin(HP_All_Alt_Speed_160_y, HP_All_Alt_Speed_160_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_180_x{13.446, 16.215, 19.808, 24.385, 30.503};
# const std::vector<double>HP_All_Alt_Speed_180_y{-0.155, 10.041, 20.093, 30.291, 40.561};
# auto hp_a_ = lin(HP_All_Alt_Speed_180_y, HP_All_Alt_Speed_180_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_200_x{15.040, 18.022, 21.802, 27.016, 33.480};
# const std::vector<double>HP_All_Alt_Speed_200_y{-0.155, 9.897, 19.805, 30.292, 40.129};
# auto hp_a_ = lin(HP_All_Alt_Speed_200_y, HP_All_Alt_Speed_200_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_220_x{16.582, 19.909, 24.061, 29.647, 35.047};
# const std::vector<double>HP_All_Alt_Speed_220_y{-0.226, 10.043, 20.023, 30.366, 38.322};
# auto hp_a_ = lin(HP_All_Alt_Speed_220_y, HP_All_Alt_Speed_220_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_240_x{18.097, 21.637, 26.187, 32.092, 35.018};
# const std::vector<double>HP_All_Alt_Speed_240_y{-0.225, 9.971, 20.096, 30.150, 34.417};
# auto hp_a_ = lin(HP_All_Alt_Speed_240_y, HP_All_Alt_Speed_240_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_260_x{19.665, 23.338, 28.393, 34.591, 35.070};
# const std::vector<double>HP_All_Alt_Speed_260_y{-0.225, 9.900, 20.025, 30.151, 31.019};
# auto hp_a_ = lin(HP_All_Alt_Speed_260_y, HP_All_Alt_Speed_260_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_280_x{21.153, 25.278, 30.413, 34.935};
# const std::vector<double>HP_All_Alt_Speed_280_y{-0.224, 9.973, 20.026, 27.838};
# auto hp_a_ = lin(HP_All_Alt_Speed_280_y, HP_All_Alt_Speed_280_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_300_x{22.721, 27.059, 32.539, 35.039};
# const std::vector<double>HP_All_Alt_Speed_300_y{-0.223, 9.974, 19.955, 24.150};
# auto hp_a_ = lin(HP_All_Alt_Speed_300_y, HP_All_Alt_Speed_300_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_320_x{24.236, 28.839, 34.585, 35.038};
# const std::vector<double>HP_All_Alt_Speed_320_y{-0.150, 9.903, 20.101, 20.896};
# auto hp_a_ = lin(HP_All_Alt_Speed_320_y, HP_All_Alt_Speed_320_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_340_x{25.751, 30.461, 35.062};
# const std::vector<double>HP_All_Alt_Speed_340_y{-0.005, 9.976, 17.570};
# auto hp_a_ = lin(HP_All_Alt_Speed_340_y, HP_All_Alt_Speed_340_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_360_x{27.239, 32.454, 35.008};
# const std::vector<double>HP_All_Alt_Speed_360_y{-0.076, 9.977, 14.533};
# auto hp_a_ = lin(HP_All_Alt_Speed_360_y, HP_All_Alt_Speed_360_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_380_x{28.781, 33.969, 35.033};
# const std::vector<double>HP_All_Alt_Speed_380_y{-0.220, 10.050, 11.497};
# auto hp_a_ = lin(HP_All_Alt_Speed_380_y, HP_All_Alt_Speed_380_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_400_x{30.322, 32.504, 35.004};
# const std::vector<double>HP_All_Alt_Speed_400_y{-0.219, 4.409, 8.532};
# auto hp_a_ = lin(HP_All_Alt_Speed_400_y, HP_All_Alt_Speed_400_x, alt_div_1000);
#
#
# const std::vector<double>HP_All_Alt_Speed_420_x{32.581, 35.002};
# const std::vector<double>HP_All_Alt_Speed_420_y{-0.074, 4.628};
# auto hp_a_ = lin(HP_All_Alt_Speed_420_y, HP_All_Alt_Speed_420_x, alt_div_1000);

# %%
DIG_FILE_NAME = "HP_All_Alt_Temp.dig"
X_AXIS_NAME = "pwr_ref_a"
Y_NAME = "OAT"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto hp_ta_ = lin({x_nm}_x, {c_clean}_y, hp_all_res);")
    print("\n")
# Out:
# const std::vector<double>HP_All_oat__60_x{-0.088, 4.801, 9.857, 14.915, 19.907, 24.933, 29.892, 35.021};
# const std::vector<double>HP_All_oat__60_y{35.992, 36.077, 37.244, 40.170, 45.126, 51.750, 60.133, 70.590};
# auto hp_ta_ = lin(HP_All_oat__60_x, HP_All_oat__60_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat__50_x{-0.020, 4.801, 9.892, 14.949, 19.907, 24.866, 29.959, 35.054};
# const std::vector<double>HP_All_oat__50_y{37.074, 37.295, 38.597, 41.658, 46.253, 52.246, 60.133, 69.462};
# auto hp_ta_ = lin(HP_All_oat__50_x, HP_All_oat__50_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat__40_x{-0.121, 4.768, 9.892, 14.915, 19.873, 24.899, 29.924, 35.051};
# const std::vector<double>HP_All_oat__40_y{37.254, 37.565, 38.417, 41.027, 45.171, 50.893, 57.202, 64.998};
# auto hp_ta_ = lin(HP_All_oat__40_x, HP_All_oat__40_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat__30_x{-0.088, 4.801, 9.891, 14.948, 19.972, 24.997, 29.956, 35.116};
# const std::vector<double>HP_All_oat__30_y{35.811, 35.942, 36.929, 39.178, 42.510, 47.105, 53.053, 60.082};
# auto hp_ta_ = lin(HP_All_oat__30_x, HP_All_oat__30_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat__20_x{-0.090, 4.832, 9.956, 14.979, 19.970, 24.928, 29.919, 35.045};
# const std::vector<double>HP_All_oat__20_y{32.474, 32.650, 33.637, 35.480, 38.587, 43.001, 47.821, 53.588};
# auto hp_ta_ = lin(HP_All_oat__20_x, HP_All_oat__20_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat__10_x{-0.092, 4.830, 9.887, 14.910, 19.934, 24.958, 30.117, 35.042};
# const std::vector<double>HP_All_oat__10_y{28.731, 28.862, 29.758, 31.377, 33.897, 37.319, 41.823, 46.869};
# auto hp_ta_ = lin(HP_All_oat__10_x, HP_All_oat__10_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_0_x{-0.094, 4.794, 9.918, 14.941, 19.931, 24.855, 29.946, 35.038};
# const std::vector<double>HP_All_oat_0_y{23.951, 23.946, 24.617, 26.236, 28.575, 31.637, 35.781, 40.556};
# auto hp_ta_ = lin(HP_All_oat_0_x, HP_All_oat_0_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_10_x{-0.130, 4.792, 9.882, 14.938, 19.962, 24.919, 29.910, 35.035};
# const std::vector<double>HP_All_oat_10_y{18.990, 19.076, 19.747, 21.049, 23.389, 26.270, 30.144, 34.964};
# auto hp_ta_ = lin(HP_All_oat_10_x, HP_All_oat_10_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_20_x{-0.099, 4.789, 9.946, 14.936, 19.892, 24.916, 29.941, 35.066};
# const std::vector<double>HP_All_oat_20_y{14.345, 14.386, 14.786, 16.224, 18.384, 21.220, 25.003, 29.958};
# auto hp_ta_ = lin(HP_All_oat_20_x, HP_All_oat_20_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_30_x{-0.135, 4.820, 9.944, 14.933, 19.923, 24.880, 29.905, 35.031};
# const std::vector<double>HP_All_oat_30_y{10.016, 9.831, 10.547, 11.760, 13.829, 16.755, 20.944, 27.117};
# auto hp_ta_ = lin(HP_All_oat_30_x, HP_All_oat_30_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_40_x{-0.104, 4.852, 10.008, 14.864, 19.888, 24.879, 27.324, 29.937, 34.998};
# const std::vector<double>HP_All_oat_40_y{5.867, 5.907, 6.534, 7.746, 10.041, 13.553, 15.535, 18.960, 27.072};
# auto hp_ta_ = lin(HP_All_oat_40_x, HP_All_oat_40_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_50_x{-0.173, 4.816, 9.973, 14.863, 19.886, 24.912, 29.904, 35.065};
# const std::vector<double>HP_All_oat_50_y{2.666, 2.570, 3.287, 4.950, 7.470, 12.471, 18.960, 27.117};
# auto hp_ta_ = lin(HP_All_oat_50_x, HP_All_oat_50_y, hp_all_res);
#
#
# const std::vector<double>HP_All_oat_60_x{-0.174, 4.916, 9.905, 14.929, 19.886, 24.912, 29.904, 35.098};
# const std::vector<double>HP_All_oat_60_y{0.185, 0.586, 1.573, 3.913, 7.516, 12.381, 18.960, 27.252};
# auto hp_ta_ = lin(HP_All_oat_60_x, HP_All_oat_60_y, hp_all_res);

# %%
DIG_FILE_NAME = "HP_All_Temp_Alt_PRN.dig"
X_AXIS_NAME = "pwr_ref"
Y_NAME = "altitude"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto hp_a_pxalt_ = lin({c_clean}_y, {x_nm}_x, hp_all_res_2);")
    print("\n")
# Out:
# const std::vector<double>HP_All_Press_alt_0_x{10.751, 15.043, 17.490, 20.038, 23.458, 23.525, 23.659};
# const std::vector<double>HP_All_Press_alt_0_y{0.041, 6.308, 10.139, 14.422, 20.869, 31.956, 70.177};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_0_y, HP_All_Press_alt_0_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_5_x{7.969, 10.517, 15.143, 19.267, 21.547, 22.485, 23.391, 23.491, 23.659};
# const std::vector<double>HP_All_Press_alt_5_y{0.040, 4.188, 13.249, 21.904, 27.088, 29.116, 31.190, 37.996, 70.177};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_5_y, HP_All_Press_alt_5_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_10_x{5.052, 7.298, 11.422, 15.981, 20.105, 22.452, 23.290, 23.424, 23.659};
# const std::vector<double>HP_All_Press_alt_10_y{0.084, 4.367, 13.698, 25.058, 36.552, 43.179, 45.793, 47.551, 70.222};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_10_y, HP_All_Press_alt_10_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_15_x{3.376, 4.951, 8.639, 11.891, 15.177, 18.194, 23.424, 23.692};
# const std::vector<double>HP_All_Press_alt_15_y{0.039, 4.186, 15.094, 25.056, 35.153, 45.070, 62.605, 70.222};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_15_y, HP_All_Press_alt_15_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_20_x{2.940, 3.107, 3.912, 7.466, 10.014, 12.562, 16.350, 20.172};
# const std::vector<double>HP_All_Press_alt_20_y{0.129, 2.968, 6.033, 20.052, 30.104, 40.065, 55.166, 70.131};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_20_y, HP_All_Press_alt_20_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_25_x{2.906, 3.007, 3.107, 5.018, 6.963, 8.807, 11.858, 14.003, 15.110};
# const std::vector<double>HP_All_Press_alt_25_y{0.084, 7.746, 9.053, 20.141, 30.103, 40.154, 54.984, 65.171, 70.174};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_25_y, HP_All_Press_alt_25_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_30_x{2.839, 3.040, 3.275, 3.945, 4.784, 6.963, 8.505, 10.986};
# const std::vector<double>HP_All_Press_alt_30_y{0.084, 18.067, 19.735, 24.197, 30.102, 45.112, 55.118, 70.128};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_30_y, HP_All_Press_alt_30_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_35_x{2.839, 3.007, 3.040, 3.443, 4.214, 5.253, 6.292, 8.036};
# const std::vector<double>HP_All_Press_alt_35_y{0.084, 24.152, 21.988, 27.262, 35.060, 45.201, 55.162, 70.172};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_35_y, HP_All_Press_alt_35_x, hp_all_res_2);
#
#
# const std::vector<double>HP_All_Press_alt_40_x{2.839, 3.040, 3.174, 3.778, 4.918, 5.789};
# const std::vector<double>HP_All_Press_alt_40_y{0.084, 25.053, 36.907, 45.156, 60.210, 70.171};
# auto hp_a_pxalt_ = lin(HP_All_Press_alt_40_y, HP_All_Press_alt_40_x, hp_all_res_2);

# %%
DIG_FILE_NAME = "HP_All_PRN_PLA.dig"
X_AXIS_NAME = "pwr_ref"
Y_NAME = "HP"
uncorr = {}
chart = ParseDig(f'./{TOP_FOLDER}/dig/{DIG_FILE_NAME}')
for c in chart.curveNames():
    xVector = [row [0] for row in chart.curve(c)]
    yVector = [row [1] for row in chart.curve(c)]
    c_clean = c.replace("-", "_")
    x_nm = c_clean
    print(f"const std::vector<double>{x_nm}_x{{" + ", ".join(['{0:.3f}'.format(s)for s in xVector]) + "};")
    
    print(f"const std::vector<double>{c_clean}_y{{" + ", ".join(['{0:.3f}'.format(s) for s in yVector]) + "};")
    print(f"auto hp_a_fref_ = lin({x_nm}_x, {c_clean}_y, hp_all_res_3);")
    print("\n")
# Out:
# const std::vector<double>HP_All_PLA_33_x{2.408, 4.946, 9.969, 15.019, 20.016, 25.066};
# const std::vector<double>HP_All_PLA_33_y{3.502, 3.330, 3.030, 2.774, 2.474, 2.261};
# auto hp_a_fref_ = lin(HP_All_PLA_33_x, HP_All_PLA_33_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_37_x{2.382, 4.946, 9.996, 15.019, 20.017, 25.041};
# const std::vector<double>HP_All_PLA_37_y{3.719, 3.852, 4.117, 4.470, 4.865, 5.261};
# auto hp_a_fref_ = lin(HP_All_PLA_37_x, HP_All_PLA_37_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_40_x{2.382, 4.920, 9.970, 14.994, 20.017, 25.041};
# const std::vector<double>HP_All_PLA_40_y{3.806, 4.243, 5.117, 5.991, 6.909, 7.739};
# auto hp_a_fref_ = lin(HP_All_PLA_40_x, HP_All_PLA_40_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_45_x{2.382, 4.946, 9.997, 14.995, 20.045, 25.069};
# const std::vector<double>HP_All_PLA_45_y{3.937, 5.070, 7.291, 9.383, 11.517, 13.739};
# auto hp_a_fref_ = lin(HP_All_PLA_45_x, HP_All_PLA_45_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_50_x{2.408, 4.947, 9.945, 14.995, 20.020, 25.044};
# const std::vector<double>HP_All_PLA_50_y{4.111, 5.722, 9.030, 12.296, 15.691, 19.044};
# auto hp_a_fref_ = lin(HP_All_PLA_50_x, HP_All_PLA_50_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_55_x{2.356, 4.947, 9.998, 15.022, 20.047, 25.046};
# const std::vector<double>HP_All_PLA_55_y{4.285, 6.504, 11.030, 15.600, 20.257, 24.826};
# auto hp_a_fref_ = lin(HP_All_PLA_55_x, HP_All_PLA_55_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_60_x{2.330, 4.973, 9.972, 15.023, 20.048, 25.047};
# const std::vector<double>HP_All_PLA_60_y{4.372, 7.157, 12.857, 18.557, 24.300, 30.000};
# auto hp_a_fref_ = lin(HP_All_PLA_60_x, HP_All_PLA_60_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_65_x{2.382, 4.947, 9.972, 14.998, 20.023, 25.075};
# const std::vector<double>HP_All_PLA_65_y{4.633, 7.939, 14.813, 21.730, 28.648, 35.565};
# auto hp_a_fref_ = lin(HP_All_PLA_65_x, HP_All_PLA_65_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_70_x{2.382, 4.947, 9.973, 14.999, 20.050, 25.076};
# const std::vector<double>HP_All_PLA_70_y{4.589, 8.635, 16.639, 24.730, 32.865, 40.870};
# auto hp_a_fref_ = lin(HP_All_PLA_70_x, HP_All_PLA_70_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_75_x{2.356, 4.921, 9.973, 14.999, 20.052, 25.051};
# const std::vector<double>HP_All_PLA_75_y{4.806, 9.287, 18.596, 27.991, 37.213, 46.478};
# auto hp_a_fref_ = lin(HP_All_PLA_75_x, HP_All_PLA_75_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_77.5_x{2.408, 4.921, 9.974, 15.000, 20.026, 24.633, 25.130};
# const std::vector<double>HP_All_PLA_77.5_y{4.893, 9.548, 19.248, 28.817, 38.344, 47.174, 47.261};
# auto hp_a_fref_ = lin(HP_All_PLA_77.5_x, HP_All_PLA_77.5_y, hp_all_res_3);
#
#
# const std::vector<double>HP_All_PLA_85_x{2.408, 4.921, 9.974, 15.026, 20.026, 23.377, 23.560, 24.555, 25.078};
# const std::vector<double>HP_All_PLA_85_y{5.024, 9.983, 20.117, 30.122, 40.126, 46.868, 47.173, 47.304, 47.174};
# auto hp_a_fref_ = lin(HP_All_PLA_85_x, HP_All_PLA_85_y, hp_all_res_3);
